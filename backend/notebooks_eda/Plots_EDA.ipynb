# %% [markdown]
# # Plots for Presentation

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import seaborn as sns

# %%
df_big = pd.read_csv("../data/data.csv")

# %%
df_training = pd.read_csv("../data/data_multiclass_with_none.csv")

# %% [markdown]
# ### Load Stylesheet

# %%
plt.style.use('stylesheet.mplstyle')

# %% [markdown]
# ### Plots for big Dataset

# %%
df_big = df_big[df_big["logical_fallacies"] != "faulty_generalization"]

# %%
df_big['logical_fallacies'].value_counts().sort_index(ascending=True)
# Out:
# logical_fallacies
# ad_hominem             1062
# appeal_to_authority     726
# appeal_to_emotion      1619
# false_dilemma           941
# none                   5418
# slippery_slope          627
# Name: count, dtype: int64

# %%
# Create pie chart using stylesheet
fig, ax = plt.subplots()
labels= ["Ad Hominem", "Appeal to Authority", "Appeal to Emotion", "False Dilemma", "None", "Slippery Slope"]
ax.pie(df_big['logical_fallacies'].value_counts().sort_index(ascending=True), labels=labels, autopct='%1.1f%%', startangle=90)
ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
# Out:
# (-1.0999999990109528,
#  1.099999979231865,
#  -1.0999997387259979,
#  1.0999999875583808)

# %% [markdown]
# ### Plots for small Dataset

# %%
# Create pie chart using stylesheet
fig, ax = plt.subplots()
labels= ["Ad Hominem", "Appeal to Authority", "Appeal to Emotion", "False Dilemma", "None", "Slippery Slope"]
ax.pie(df_training['logical_fallacies'].value_counts().sort_index(ascending=True), labels=labels, autopct='%1.1f%%', startangle=90)
ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
# Out:
# (-1.0999999610370534,
#  1.099999995896473,
#  -1.0999999997563108,
#  1.0999999999883958)
