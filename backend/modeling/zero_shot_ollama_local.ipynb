# %% [markdown]
# # Zero shot using LLM with Ollama locally

# %% [markdown]
# ### Import necessary packages

# %% [markdown]
# Before coding, you need to do this in your terminal:
# 1. brew install ollama (install ollama framework for starting LLMs locally)
# 2. pip install langchain-ollama (in virtual environment)
# 2. ollama serve (start ollama server)
# 3. get model name from: https://ollama.com/library/
# 4. ollama run name_of_model_from_ollama (e.g. llama3.1:8b; in second terminal; downloads model and runs it)

# %%
import pandas as pd
import os
from tqdm import tqdm
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

import warnings
warnings.filterwarnings("ignore")

from langchain_groq import ChatGroq
from langchain_ollama import OllamaLLM
import warnings
warnings.filterwarnings("ignore")

import mlflow
from mlflow.sklearn import save_model
from mlflow.transformers import log_model
import logging

import config

# %% [markdown]
# ### Setup

# %%
MODEL_NAME = "deepseek" 
TRACKING_URI = open("../.mlflow_uri").read().strip()
EXPERIMENT_NAME = config.EXPERIMENT_NAME

logging.basicConfig(format="%(asctime)s: %(message)s") # Configure logging format to show timestamp before every message

logger = logging.getLogger()
logger.setLevel(logging.INFO) # Only show logs that are INFO or more important (e.g., WARNING, ERROR) — but ignore DEBUG.

# %%
DATA_PATH = "../data/data_dropped_duplicates_small.csv"
SAVE_PATH = "../models/DeepSeek"

# %% [markdown]
# ### Get data

# %%
df = pd.read_csv(DATA_PATH)

# %% [markdown]
# ### Initialize local model using Ollama

# %%
#temperature is hyperparameter, how creative do I want the llm to be (0 is not creative), sometimes, when it is not 0, it can give you the second likely word

# Initialize the local Llama model using Ollama
llm = OllamaLLM(
    model="deepseek-r1:8b",  # llama3.1:8b, Replace with your desired local Llama model version
    # temperature=0,        # no randomness, deterministic output
    max_tokens=None,      # unlimited token length (adjust as needed)
)

# %%
params = {
      #"temperature": 0,
      "max_tokens": None,
  }
  
# setting the MLFlow connection and experiment
mlflow.set_tracking_uri(TRACKING_URI)
mlflow.set_experiment(EXPERIMENT_NAME)

mlflow.start_run()
run = mlflow.active_run()
print("Active run_id: {}".format(run.info.run_id))

mlflow.set_tag("model_name", MODEL_NAME)
mlflow.set_tag('mlflow.runName', 'deepseek-r1:8b')
mlflow.log_params(params)
# Out:
# Active run_id: ec2ca99970f943daac67b393bdd123e7

# %% [markdown]
# ### Define a prompt

# %%
import re


def classify_fallacy(text: str) -> str:
    """Classifies text into one of the predefined logical fallacies."""
    try:
        prompt = f"""Classify the text below into exactly one logical fallacy category:
- faulty_generalization
- ad_hominem
- false_dilemma 
- appeal_to_authority
- appeal_to_emotion  
- none

**Rules**:
- Use ONLY the exact category names above
- If no fallacy matches, use "none"
- No explanations, only the category name

Here are definitions of each category for reference:
1. **Faulty Generalization**: This fallacy occurs when an argument assumes something is true for a large population without having a large enough sample. A kind of overgeneralization.
2. **Ad Hominem**: This fallacy occurs when the speaker is attacking the other person or some aspect of them rather than addressing the argument itself.
3. **False Dilemma**: This fallacy occurs when only two options are presented in an argument, even though more options may exist. A case of “either this or that”.
4. **Appeal to Authority**: This fallacy occurs when an argument relies on the opinion or endorsement of an authority figure who may not have relevant expertise or whose expertise is questionable.
5. **Appeal to Emotion**: This fallacy occurs when emotion is used to support an argument, such as pity, fear, anger, etc.
6. **None**: There are no fallacies in this text!

Here are examples of each category for reference:
1. **Faulty Generalization**: "I read one report about corruption, so that industry must be corrupt."
2. **Ad Hominem**: "Do you even know what you're talking about?"
3. **False Dilemma**: "Do you recommend drinking or injecting bleach to fight Covid?"
4. **Appeal to Authority**: "Trust me, I am a lawyer, so I know how to handle your taxes."
5. **Appeal to Emotion**: "You murdered 100,000 people, called Coronavirus a hoax, fired doctors, and told Americans to inject themselves with bleach. Maybe you should shut the fuck up."
6. **None**: "I don't think that kind of logic is good. It's essentially saying that so long as the authoritarians repress their people enough and nobody can rise up against them, we should think things are okay. We should strive to ensure they have leaders who value democracy, not oppression and authoritarianism."

Text to classify: {text}

."""

        # Generate response using the local Llama model
        response = llm.invoke(prompt)
        
        # for deepseek, remove <think>...</think> tags
        # Remove <think>...</think> tags and line breaks
        response = re.sub(r"<think>.*?</think>", "", response, flags=re.DOTALL).strip()

        # Extract and normalize response content
        prediction = response.strip().lower()
        valid_categories = ["faulty_generalization", "ad_hominem", "false_dilemma", 
                            "appeal_to_authority", "appeal_to_emotion", "none"]
        
        return prediction if prediction in valid_categories else "error" #else "none"
        
    except Exception as e:
        print(f"Error processing text: {text[:50]}... | Error: {str(e)}")
        return "error"

# %% [markdown]
# ### Process dataframe

# %%
def process_dataframe(df: pd.DataFrame, batch_size=10) -> pd.DataFrame:
    """Process DataFrame with chunking for better performance."""
    result_df = df.copy()
    
    # Process in smaller batches to reduce errors
    chunks = [df[i:i+batch_size] for i in range(0, len(df), batch_size)]
    
    with tqdm(total=len(df), desc="Classifying Logical Fallacies") as pbar: #tqdm progresses bar
        for chunk in chunks:
            chunk_results = []
            for text in chunk['text']:
                result = classify_fallacy(text)
                chunk_results.append(result)
                pbar.update(1)
                
            # Update results for this chunk
            result_df.loc[chunk.index, 'predicted_fallacy'] = chunk_results
    
    return result_df

# %% [markdown]
# ### Make predictions

# %%
# make predictions only based on 1000 rows
df_small = df.iloc[:1000]

# %%
logger.info('prediction of logical fallacies')
# Process the DataFrame and classify logical fallacies
processed_df = process_dataframe(df_small)
# Out:
# 2025-04-07 14:56:31,155: prediction of logical fallacies
# Classifying Logical Fallacies:   0%|          | 0/1000 [00:00<?, ?it/s]2025-04-07 14:56:33,733: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   0%|          | 1/1000 [00:12<3:29:16, 12.57s/it]2025-04-07 14:56:44,562: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   0%|          | 2/1000 [00:32<4:37:56, 16.71s/it]2025-04-07 14:57:03,573: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   0%|          | 3/1000 [00:47<4:30:49, 16.30s/it]2025-04-07 14:57:19,364: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   0%|          | 4/1000 [01:01<4:11:20, 15.14s/it]2025-04-07 14:57:33,056: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   0%|          | 5/1000 [01:23<4:55:54, 17.84s/it]2025-04-07 14:57:55,540: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   1%|          | 6/1000 [01:37<4:31:12, 16.37s/it]2025-04-07 14:58:09,046: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   1%|          | 7/1000 [01:58<4:55:52, 17.88s/it]2025-04-07 14:58:30,020: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   1%|          | 8/1000 [02:19<5:13:08, 18.94s/it]2025-04-07 14:58:51,074: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   1%|          | 9/1000 [02:36<4:59:40, 18.14s/it]2025-04-07 14:59:07,474: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   1%|          | 10/1000 [02:56<5:10:32, 18.82s/it]2025-04-07 14:59:27,983: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   1%|          | 11/1000 [03:09<4:40:54, 17.04s/it]2025-04-07 14:59:40,806: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   1%|          | 12/1000 [03:28<4:48:34, 17.53s/it]2025-04-07 14:59:59,603: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   1%|▏         | 13/1000 [03:59<5:57:34, 21.74s/it]2025-04-07 15:00:31,039: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   1%|▏         | 14/1000 [04:22<6:02:00, 22.03s/it]2025-04-07 15:00:53,741: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   2%|▏         | 15/1000 [04:43<5:59:17, 21.89s/it]2025-04-07 15:01:15,152: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   2%|▏         | 16/1000 [04:56<5:14:35, 19.18s/it]2025-04-07 15:01:28,653: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   2%|▏         | 17/1000 [05:23<5:52:36, 21.52s/it]2025-04-07 15:01:55,202: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   2%|▏         | 18/1000 [06:13<8:12:53, 30.12s/it]2025-04-07 15:02:45,292: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   2%|▏         | 19/1000 [06:29<7:01:02, 25.75s/it]2025-04-07 15:03:00,716: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   2%|▏         | 20/1000 [06:43<6:03:39, 22.26s/it]2025-04-07 15:03:15,037: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   2%|▏         | 21/1000 [07:06<6:07:33, 22.53s/it]2025-04-07 15:03:37,983: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   2%|▏         | 22/1000 [07:30<6:12:07, 22.83s/it]2025-04-07 15:04:01,688: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   2%|▏         | 23/1000 [07:47<5:46:26, 21.28s/it]2025-04-07 15:04:19,656: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   2%|▏         | 24/1000 [08:08<5:44:08, 21.16s/it]2025-04-07 15:04:40,198: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   2%|▎         | 25/1000 [08:31<5:51:24, 21.63s/it]2025-04-07 15:05:02,951: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   3%|▎         | 26/1000 [08:55<6:03:15, 22.38s/it]2025-04-07 15:05:27,067: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   3%|▎         | 27/1000 [09:20<6:17:58, 23.31s/it]2025-04-07 15:05:52,550: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   3%|▎         | 28/1000 [09:42<6:08:47, 22.77s/it]2025-04-07 15:06:14,041: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   3%|▎         | 29/1000 [10:05<6:08:11, 22.75s/it]2025-04-07 15:06:36,615: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   3%|▎         | 30/1000 [10:36<6:50:41, 25.40s/it]2025-04-07 15:07:08,233: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   3%|▎         | 31/1000 [10:54<6:13:04, 23.10s/it]2025-04-07 15:07:25,908: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   3%|▎         | 32/1000 [11:04<5:10:22, 19.24s/it]2025-04-07 15:07:36,138: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   3%|▎         | 33/1000 [11:18<4:41:43, 17.48s/it]2025-04-07 15:07:49,974: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   3%|▎         | 34/1000 [11:33<4:28:53, 16.70s/it]2025-04-07 15:08:04,594: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   4%|▎         | 35/1000 [11:50<4:32:24, 16.94s/it]2025-04-07 15:08:22,041: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   4%|▎         | 36/1000 [12:13<5:00:02, 18.67s/it]2025-04-07 15:08:44,781: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   4%|▎         | 37/1000 [12:36<5:20:14, 19.95s/it]2025-04-07 15:09:07,708: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   4%|▍         | 38/1000 [12:59<5:34:39, 20.87s/it]2025-04-07 15:09:31,158: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   4%|▍         | 39/1000 [13:17<5:22:33, 20.14s/it]2025-04-07 15:09:49,294: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   4%|▍         | 40/1000 [13:45<6:01:39, 22.60s/it]2025-04-07 15:10:17,512: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   4%|▍         | 41/1000 [14:10<6:12:40, 23.32s/it]2025-04-07 15:10:42,497: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   4%|▍         | 42/1000 [14:31<5:59:44, 22.53s/it]2025-04-07 15:11:03,035: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   4%|▍         | 43/1000 [14:47<5:28:10, 20.58s/it]2025-04-07 15:11:19,197: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   4%|▍         | 44/1000 [15:07<5:23:06, 20.28s/it]2025-04-07 15:11:38,782: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   4%|▍         | 45/1000 [15:21<4:54:10, 18.48s/it]2025-04-07 15:11:52,875: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   5%|▍         | 46/1000 [15:41<5:00:11, 18.88s/it]2025-04-07 15:12:12,882: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   5%|▍         | 47/1000 [16:09<5:43:35, 21.63s/it]2025-04-07 15:12:40,782: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   5%|▍         | 48/1000 [16:27<5:27:04, 20.61s/it]2025-04-07 15:12:59,310: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   5%|▍         | 49/1000 [16:47<5:23:19, 20.40s/it]2025-04-07 15:13:18,898: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   5%|▌         | 50/1000 [17:03<5:03:39, 19.18s/it]2025-04-07 15:13:35,246: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   5%|▌         | 51/1000 [17:16<4:33:32, 17.29s/it]2025-04-07 15:13:48,297: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   5%|▌         | 52/1000 [17:35<4:41:40, 17.83s/it]2025-04-07 15:14:07,227: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   5%|▌         | 53/1000 [17:50<4:25:53, 16.85s/it]2025-04-07 15:14:21,780: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   5%|▌         | 54/1000 [18:05<4:17:23, 16.33s/it]2025-04-07 15:14:37,039: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   6%|▌         | 55/1000 [18:37<5:29:11, 20.90s/it]2025-04-07 15:15:08,630: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   6%|▌         | 56/1000 [18:56<5:20:43, 20.38s/it]2025-04-07 15:15:27,805: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   6%|▌         | 57/1000 [19:08<4:42:50, 18.00s/it]2025-04-07 15:15:40,063: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   6%|▌         | 58/1000 [19:23<4:25:32, 16.91s/it]2025-04-07 15:15:54,448: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   6%|▌         | 59/1000 [19:43<4:39:47, 17.84s/it]2025-04-07 15:16:14,747: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   6%|▌         | 60/1000 [20:10<5:25:54, 20.80s/it]2025-04-07 15:16:42,329: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   6%|▌         | 61/1000 [20:30<5:21:24, 20.54s/it]2025-04-07 15:17:02,253: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   6%|▌         | 62/1000 [20:43<4:46:58, 18.36s/it]2025-04-07 15:17:15,538: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   6%|▋         | 63/1000 [21:08<5:15:14, 20.19s/it]2025-04-07 15:17:39,804: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   6%|▋         | 64/1000 [21:28<5:16:01, 20.26s/it]2025-04-07 15:18:00,394: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   6%|▋         | 65/1000 [21:56<5:51:16, 22.54s/it]2025-04-07 15:18:28,265: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   7%|▋         | 66/1000 [22:16<5:38:08, 21.72s/it]2025-04-07 15:18:48,077: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   7%|▋         | 67/1000 [22:37<5:35:47, 21.59s/it]2025-04-07 15:19:09,235: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   7%|▋         | 68/1000 [22:50<4:51:46, 18.78s/it]2025-04-07 15:19:21,589: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   7%|▋         | 69/1000 [23:08<4:48:05, 18.57s/it]2025-04-07 15:19:39,498: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   7%|▋         | 70/1000 [23:24<4:37:13, 17.89s/it]2025-04-07 15:19:55,795: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   7%|▋         | 71/1000 [23:37<4:16:19, 16.55s/it]2025-04-07 15:20:09,247: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   7%|▋         | 72/1000 [23:54<4:18:29, 16.71s/it]2025-04-07 15:20:26,325: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   7%|▋         | 73/1000 [24:11<4:15:32, 16.54s/it]2025-04-07 15:20:42,758: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   7%|▋         | 74/1000 [24:37<5:01:31, 19.54s/it]2025-04-07 15:21:09,019: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   8%|▊         | 75/1000 [24:49<4:23:41, 17.10s/it]2025-04-07 15:21:20,421: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   8%|▊         | 76/1000 [25:22<5:41:05, 22.15s/it]2025-04-07 15:21:54,502: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   8%|▊         | 77/1000 [25:43<5:31:47, 21.57s/it]2025-04-07 15:22:14,704: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   8%|▊         | 78/1000 [26:06<5:41:03, 22.19s/it]2025-04-07 15:22:38,511: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   8%|▊         | 79/1000 [26:18<4:51:24, 18.98s/it]2025-04-07 15:22:49,700: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   8%|▊         | 80/1000 [26:32<4:28:02, 17.48s/it]2025-04-07 15:23:03,836: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   8%|▊         | 81/1000 [27:16<6:32:05, 25.60s/it]2025-04-07 15:23:48,373: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   8%|▊         | 82/1000 [27:47<6:56:24, 27.22s/it]2025-04-07 15:24:19,172: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   8%|▊         | 83/1000 [28:06<6:15:12, 24.55s/it]2025-04-07 15:24:37,992: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   8%|▊         | 84/1000 [28:29<6:08:17, 24.12s/it]2025-04-07 15:25:00,958: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   8%|▊         | 85/1000 [28:47<5:39:19, 22.25s/it]2025-04-07 15:25:18,708: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   9%|▊         | 86/1000 [29:09<5:40:10, 22.33s/it]2025-04-07 15:25:41,088: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   9%|▊         | 87/1000 [29:50<7:03:48, 27.85s/it]2025-04-07 15:26:22,127: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   9%|▉         | 88/1000 [29:59<5:39:29, 22.34s/it]2025-04-07 15:26:31,267: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   9%|▉         | 89/1000 [30:15<5:09:10, 20.36s/it]2025-04-07 15:26:47,186: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   9%|▉         | 90/1000 [30:35<5:06:34, 20.21s/it]2025-04-07 15:27:07,228: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   9%|▉         | 91/1000 [30:58<5:17:58, 20.99s/it]2025-04-07 15:27:30,157: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   9%|▉         | 92/1000 [31:15<4:58:42, 19.74s/it]2025-04-07 15:27:46,534: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   9%|▉         | 93/1000 [31:26<4:19:07, 17.14s/it]2025-04-07 15:27:57,598: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   9%|▉         | 94/1000 [31:41<4:08:21, 16.45s/it]2025-04-07 15:28:12,426: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  10%|▉         | 95/1000 [32:00<4:19:41, 17.22s/it]2025-04-07 15:28:31,591: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  10%|▉         | 96/1000 [32:22<4:42:03, 18.72s/it]2025-04-07 15:28:53,819: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  10%|▉         | 97/1000 [32:35<4:16:58, 17.08s/it]2025-04-07 15:29:06,930: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  10%|▉         | 98/1000 [32:50<4:08:11, 16.51s/it]2025-04-07 15:29:22,869: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  10%|▉         | 99/1000 [33:12<4:31:58, 18.11s/it]2025-04-07 15:29:44,100: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  10%|█         | 100/1000 [33:32<4:41:21, 18.76s/it]2025-04-07 15:30:04,649: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  10%|█         | 101/1000 [33:46<4:19:48, 17.34s/it]2025-04-07 15:30:18,237: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  10%|█         | 102/1000 [34:07<4:32:38, 18.22s/it]2025-04-07 15:30:39,296: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  10%|█         | 103/1000 [34:31<4:58:12, 19.95s/it]2025-04-07 15:31:02,498: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  10%|█         | 104/1000 [34:52<5:04:03, 20.36s/it]2025-04-07 15:31:24,113: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  10%|█         | 105/1000 [35:22<5:48:47, 23.38s/it]2025-04-07 15:31:54,565: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  11%|█         | 106/1000 [35:48<5:57:08, 23.97s/it]2025-04-07 15:32:19,884: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  11%|█         | 107/1000 [36:06<5:31:24, 22.27s/it]2025-04-07 15:32:37,889: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  11%|█         | 108/1000 [36:26<5:21:43, 21.64s/it]2025-04-07 15:32:58,048: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  11%|█         | 109/1000 [36:44<5:03:51, 20.46s/it]2025-04-07 15:33:15,925: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  11%|█         | 110/1000 [37:10<5:26:48, 22.03s/it]2025-04-07 15:33:41,427: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  11%|█         | 111/1000 [37:24<4:53:53, 19.83s/it]2025-04-07 15:33:56,337: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  11%|█         | 112/1000 [37:49<5:13:26, 21.18s/it]2025-04-07 15:34:20,649: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  11%|█▏        | 113/1000 [38:11<5:17:22, 21.47s/it]2025-04-07 15:34:42,643: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  11%|█▏        | 114/1000 [38:22<4:31:14, 18.37s/it]2025-04-07 15:34:54,082: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  12%|█▏        | 115/1000 [38:46<4:55:58, 20.07s/it]2025-04-07 15:35:18,254: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  12%|█▏        | 116/1000 [39:06<4:54:42, 20.00s/it]2025-04-07 15:35:37,815: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  12%|█▏        | 117/1000 [39:20<4:28:05, 18.22s/it]2025-04-07 15:35:51,849: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  12%|█▏        | 118/1000 [39:37<4:24:57, 18.02s/it]2025-04-07 15:36:09,421: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  12%|█▏        | 119/1000 [39:58<4:35:28, 18.76s/it]2025-04-07 15:36:29,755: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  12%|█▏        | 120/1000 [40:15<4:28:31, 18.31s/it]2025-04-07 15:36:46,993: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  12%|█▏        | 121/1000 [40:34<4:31:34, 18.54s/it]2025-04-07 15:37:06,257: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  12%|█▏        | 122/1000 [40:48<4:09:51, 17.07s/it]2025-04-07 15:37:20,034: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  12%|█▏        | 123/1000 [41:05<4:09:43, 17.09s/it]2025-04-07 15:37:36,840: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  12%|█▏        | 124/1000 [41:19<3:56:44, 16.22s/it]2025-04-07 15:37:51,190: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  12%|█▎        | 125/1000 [41:36<3:59:20, 16.41s/it]2025-04-07 15:38:07,921: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  13%|█▎        | 126/1000 [41:50<3:49:18, 15.74s/it]2025-04-07 15:38:22,235: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  13%|█▎        | 127/1000 [42:26<5:18:41, 21.90s/it]2025-04-07 15:38:58,525: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  13%|█▎        | 128/1000 [42:48<5:15:40, 21.72s/it]2025-04-07 15:39:19,816: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  13%|█▎        | 129/1000 [43:11<5:20:44, 22.09s/it]2025-04-07 15:39:42,929: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  13%|█▎        | 130/1000 [43:38<5:45:00, 23.79s/it]2025-04-07 15:40:10,384: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  13%|█▎        | 131/1000 [43:58<5:24:20, 22.39s/it]2025-04-07 15:40:29,837: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  13%|█▎        | 132/1000 [44:24<5:40:53, 23.56s/it]2025-04-07 15:40:56,280: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  13%|█▎        | 133/1000 [44:44<5:25:58, 22.56s/it]2025-04-07 15:41:16,031: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  13%|█▎        | 134/1000 [45:02<5:07:10, 21.28s/it]2025-04-07 15:41:34,321: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  14%|█▎        | 135/1000 [45:20<4:50:09, 20.13s/it]2025-04-07 15:41:51,756: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  14%|█▎        | 136/1000 [45:39<4:44:38, 19.77s/it]2025-04-07 15:42:11,145: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  14%|█▎        | 137/1000 [46:10<5:33:48, 23.21s/it]2025-04-07 15:42:42,085: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  14%|█▍        | 138/1000 [46:43<6:13:48, 26.02s/it]2025-04-07 15:43:14,651: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  14%|█▍        | 139/1000 [47:01<5:39:12, 23.64s/it]2025-04-07 15:43:32,727: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  14%|█▍        | 140/1000 [47:10<4:35:35, 19.23s/it]2025-04-07 15:43:41,517: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  14%|█▍        | 141/1000 [47:28<4:29:35, 18.83s/it]2025-04-07 15:43:59,421: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  14%|█▍        | 142/1000 [47:38<3:55:31, 16.47s/it]2025-04-07 15:44:10,380: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  14%|█▍        | 143/1000 [47:50<3:35:53, 15.12s/it]2025-04-07 15:44:22,343: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  14%|█▍        | 144/1000 [48:22<4:47:08, 20.13s/it]2025-04-07 15:44:54,467: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  14%|█▍        | 145/1000 [48:44<4:52:11, 20.51s/it]2025-04-07 15:45:15,559: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  15%|█▍        | 146/1000 [48:56<4:15:37, 17.96s/it]2025-04-07 15:45:27,717: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  15%|█▍        | 147/1000 [49:12<4:10:02, 17.59s/it]2025-04-07 15:45:44,629: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  15%|█▍        | 148/1000 [49:39<4:47:38, 20.26s/it]2025-04-07 15:46:11,073: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  15%|█▍        | 149/1000 [50:02<4:58:22, 21.04s/it]2025-04-07 15:46:34,085: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  15%|█▌        | 150/1000 [50:33<5:39:32, 23.97s/it]2025-04-07 15:47:04,591: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  15%|█▌        | 151/1000 [50:52<5:18:48, 22.53s/it]2025-04-07 15:47:23,937: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  15%|█▌        | 152/1000 [51:12<5:08:41, 21.84s/it]2025-04-07 15:47:43,866: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  15%|█▌        | 153/1000 [51:41<5:40:46, 24.14s/it]2025-04-07 15:48:13,642: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  15%|█▌        | 154/1000 [52:11<6:03:20, 25.77s/it]2025-04-07 15:48:43,218: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  16%|█▌        | 155/1000 [52:33<5:48:54, 24.77s/it]2025-04-07 15:49:05,379: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  16%|█▌        | 156/1000 [52:56<5:40:44, 24.22s/it]2025-04-07 15:49:28,459: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  16%|█▌        | 157/1000 [53:12<5:04:18, 21.66s/it]2025-04-07 15:49:44,280: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  16%|█▌        | 158/1000 [53:45<5:53:02, 25.16s/it]2025-04-07 15:50:17,601: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  16%|█▌        | 159/1000 [54:14<6:07:00, 26.18s/it]2025-04-07 15:50:45,880: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  16%|█▌        | 160/1000 [54:27<5:11:47, 22.27s/it]2025-04-07 15:50:59,175: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  16%|█▌        | 161/1000 [54:59<5:49:46, 25.01s/it]2025-04-07 15:51:30,596: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  16%|█▌        | 162/1000 [55:17<5:23:04, 23.13s/it]2025-04-07 15:51:49,172: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  16%|█▋        | 163/1000 [55:37<5:07:08, 22.02s/it]2025-04-07 15:52:08,889: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  16%|█▋        | 164/1000 [55:58<5:03:04, 21.75s/it]2025-04-07 15:52:29,878: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  16%|█▋        | 165/1000 [56:12<4:31:54, 19.54s/it]2025-04-07 15:52:44,261: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  17%|█▋        | 166/1000 [56:39<5:00:36, 21.63s/it]2025-04-07 15:53:10,899: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  17%|█▋        | 167/1000 [57:05<5:20:02, 23.05s/it]2025-04-07 15:53:36,992: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  17%|█▋        | 168/1000 [57:22<4:53:13, 21.15s/it]2025-04-07 15:53:53,982: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  17%|█▋        | 169/1000 [57:50<5:23:43, 23.37s/it]2025-04-07 15:54:22,437: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  17%|█▋        | 170/1000 [58:05<4:47:50, 20.81s/it]2025-04-07 15:54:37,237: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  17%|█▋        | 171/1000 [58:18<4:12:38, 18.28s/it]2025-04-07 15:54:49,456: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  17%|█▋        | 172/1000 [58:34<4:06:24, 17.86s/it]2025-04-07 15:55:06,479: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  17%|█▋        | 173/1000 [58:58<4:30:59, 19.66s/it]2025-04-07 15:55:30,361: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  17%|█▋        | 174/1000 [59:15<4:17:01, 18.67s/it]2025-04-07 15:55:46,726: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  18%|█▊        | 175/1000 [59:45<5:04:33, 22.15s/it]2025-04-07 15:56:16,834: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  18%|█▊        | 176/1000 [1:00:10<5:15:21, 22.96s/it]2025-04-07 15:56:42,026: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  18%|█▊        | 177/1000 [1:00:29<5:00:06, 21.88s/it]2025-04-07 15:57:01,203: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  18%|█▊        | 178/1000 [1:00:49<4:50:10, 21.18s/it]2025-04-07 15:57:20,576: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  18%|█▊        | 179/1000 [1:01:10<4:50:15, 21.21s/it]2025-04-07 15:57:41,928: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  18%|█▊        | 180/1000 [1:01:26<4:29:13, 19.70s/it]2025-04-07 15:57:58,075: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  18%|█▊        | 181/1000 [1:01:44<4:20:17, 19.07s/it]2025-04-07 15:58:15,812: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  18%|█▊        | 182/1000 [1:02:04<4:23:08, 19.30s/it]2025-04-07 15:58:35,652: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  18%|█▊        | 183/1000 [1:02:25<4:29:41, 19.81s/it]2025-04-07 15:58:56,464: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  18%|█▊        | 184/1000 [1:02:41<4:15:26, 18.78s/it]2025-04-07 15:59:12,861: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  18%|█▊        | 185/1000 [1:03:00<4:17:49, 18.98s/it]2025-04-07 15:59:32,447: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  19%|█▊        | 186/1000 [1:03:25<4:39:05, 20.57s/it]2025-04-07 15:59:56,739: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  19%|█▊        | 187/1000 [1:03:43<4:28:34, 19.82s/it]2025-04-07 16:00:14,971: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  19%|█▉        | 188/1000 [1:04:16<5:24:42, 23.99s/it]2025-04-07 16:00:48,687: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  19%|█▉        | 189/1000 [1:04:39<5:17:29, 23.49s/it]2025-04-07 16:01:10,851: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  19%|█▉        | 190/1000 [1:05:05<5:29:49, 24.43s/it]2025-04-07 16:01:37,629: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  19%|█▉        | 191/1000 [1:05:36<5:53:25, 26.21s/it]2025-04-07 16:02:07,840: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  19%|█▉        | 192/1000 [1:05:51<5:06:45, 22.78s/it]2025-04-07 16:02:22,622: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  19%|█▉        | 193/1000 [1:06:08<4:43:38, 21.09s/it]2025-04-07 16:02:39,905: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  19%|█▉        | 194/1000 [1:06:34<5:03:02, 22.56s/it]2025-04-07 16:03:05,581: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  20%|█▉        | 195/1000 [1:06:48<4:27:50, 19.96s/it]2025-04-07 16:03:19,496: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  20%|█▉        | 196/1000 [1:07:06<4:21:11, 19.49s/it]2025-04-07 16:03:37,906: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  20%|█▉        | 197/1000 [1:07:29<4:34:33, 20.51s/it]2025-04-07 16:04:01,251: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  20%|█▉        | 198/1000 [1:07:51<4:39:57, 20.95s/it]2025-04-07 16:04:22,744: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  20%|█▉        | 199/1000 [1:08:11<4:35:38, 20.65s/it]2025-04-07 16:04:42,611: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  20%|██        | 200/1000 [1:08:36<4:54:31, 22.09s/it]2025-04-07 16:05:08,307: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  20%|██        | 201/1000 [1:08:47<4:09:58, 18.77s/it]2025-04-07 16:05:19,480: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  20%|██        | 202/1000 [1:09:15<4:46:07, 21.51s/it]2025-04-07 16:05:47,394: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  20%|██        | 203/1000 [1:09:36<4:42:51, 21.29s/it]2025-04-07 16:06:07,873: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  20%|██        | 204/1000 [1:09:55<4:32:34, 20.55s/it]2025-04-07 16:06:26,663: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  20%|██        | 205/1000 [1:10:08<4:04:03, 18.42s/it]2025-04-07 16:06:40,282: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  21%|██        | 206/1000 [1:10:24<3:54:28, 17.72s/it]2025-04-07 16:06:56,376: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  21%|██        | 207/1000 [1:10:42<3:55:10, 17.79s/it]2025-04-07 16:07:14,350: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  21%|██        | 208/1000 [1:11:02<4:03:51, 18.47s/it]2025-04-07 16:07:34,403: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  21%|██        | 209/1000 [1:11:26<4:23:40, 20.00s/it]2025-04-07 16:07:57,823: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  21%|██        | 210/1000 [1:11:50<4:38:04, 21.12s/it]2025-04-07 16:08:21,577: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  21%|██        | 211/1000 [1:12:05<4:15:57, 19.46s/it]2025-04-07 16:08:38,067: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  21%|██        | 212/1000 [1:12:29<4:32:09, 20.72s/it]2025-04-07 16:09:01,106: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  21%|██▏       | 213/1000 [1:12:48<4:26:42, 20.33s/it]2025-04-07 16:09:20,219: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  21%|██▏       | 214/1000 [1:13:00<3:54:09, 17.87s/it]2025-04-07 16:09:32,354: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  22%|██▏       | 215/1000 [1:13:14<3:35:57, 16.51s/it]2025-04-07 16:09:45,671: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  22%|██▏       | 216/1000 [1:13:25<3:15:22, 14.95s/it]2025-04-07 16:09:57,301: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  22%|██▏       | 217/1000 [1:13:55<4:13:25, 19.42s/it]2025-04-07 16:10:27,012: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  22%|██▏       | 218/1000 [1:14:14<4:13:11, 19.43s/it]2025-04-07 16:10:46,286: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  22%|██▏       | 219/1000 [1:14:34<4:13:18, 19.46s/it]2025-04-07 16:11:05,983: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  22%|██▏       | 220/1000 [1:14:44<3:36:40, 16.67s/it]2025-04-07 16:11:16,132: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  22%|██▏       | 221/1000 [1:14:59<3:31:15, 16.27s/it]2025-04-07 16:11:31,484: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  22%|██▏       | 222/1000 [1:15:15<3:29:49, 16.18s/it]2025-04-07 16:11:47,590: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  22%|██▏       | 223/1000 [1:15:44<4:15:54, 19.76s/it]2025-04-07 16:12:15,402: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  22%|██▏       | 224/1000 [1:15:56<3:46:53, 17.54s/it]2025-04-07 16:12:27,937: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  22%|██▎       | 225/1000 [1:16:11<3:36:13, 16.74s/it]2025-04-07 16:12:42,636: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  23%|██▎       | 226/1000 [1:16:28<3:38:47, 16.96s/it]2025-04-07 16:13:00,270: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  23%|██▎       | 227/1000 [1:16:49<3:53:31, 18.13s/it]2025-04-07 16:13:21,120: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  23%|██▎       | 228/1000 [1:17:22<4:51:44, 22.67s/it]2025-04-07 16:13:54,571: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  23%|██▎       | 229/1000 [1:17:53<5:23:52, 25.20s/it]2025-04-07 16:14:25,362: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  23%|██▎       | 230/1000 [1:18:13<5:02:07, 23.54s/it]2025-04-07 16:14:45,505: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  23%|██▎       | 231/1000 [1:18:41<5:18:53, 24.88s/it]2025-04-07 16:15:13,026: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  23%|██▎       | 232/1000 [1:18:55<4:35:34, 21.53s/it]2025-04-07 16:15:26,898: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  23%|██▎       | 233/1000 [1:19:19<4:46:03, 22.38s/it]2025-04-07 16:15:51,106: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  23%|██▎       | 234/1000 [1:19:33<4:13:46, 19.88s/it]2025-04-07 16:16:05,455: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  24%|██▎       | 235/1000 [1:20:14<5:34:19, 26.22s/it]2025-04-07 16:16:46,166: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  24%|██▎       | 236/1000 [1:20:35<5:12:04, 24.51s/it]2025-04-07 16:17:06,675: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  24%|██▎       | 237/1000 [1:20:50<4:37:11, 21.80s/it]2025-04-07 16:17:22,151: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  24%|██▍       | 238/1000 [1:21:05<4:08:57, 19.60s/it]2025-04-07 16:17:36,621: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  24%|██▍       | 239/1000 [1:21:21<3:56:31, 18.65s/it]2025-04-07 16:17:53,223: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  24%|██▍       | 240/1000 [1:21:46<4:17:50, 20.36s/it]2025-04-07 16:18:17,392: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  24%|██▍       | 241/1000 [1:21:58<3:47:05, 17.95s/it]2025-04-07 16:18:29,895: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  24%|██▍       | 242/1000 [1:22:19<3:59:15, 18.94s/it]2025-04-07 16:18:50,978: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  24%|██▍       | 243/1000 [1:22:37<3:54:13, 18.57s/it]2025-04-07 16:19:09,133: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  24%|██▍       | 244/1000 [1:23:11<4:53:43, 23.31s/it]2025-04-07 16:19:43,358: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  24%|██▍       | 245/1000 [1:23:40<5:12:57, 24.87s/it]2025-04-07 16:20:11,725: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  25%|██▍       | 246/1000 [1:23:54<4:33:04, 21.73s/it]2025-04-07 16:20:26,124: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  25%|██▍       | 247/1000 [1:24:11<4:13:39, 20.21s/it]2025-04-07 16:20:42,797: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  25%|██▍       | 248/1000 [1:24:36<4:33:59, 21.86s/it]2025-04-07 16:21:08,499: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  25%|██▍       | 249/1000 [1:24:56<4:26:21, 21.28s/it]2025-04-07 16:21:28,429: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  25%|██▌       | 250/1000 [1:25:29<5:07:34, 24.61s/it]2025-04-07 16:22:00,794: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  25%|██▌       | 251/1000 [1:25:57<5:19:02, 25.56s/it]2025-04-07 16:22:28,565: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  25%|██▌       | 252/1000 [1:26:12<4:41:11, 22.56s/it]2025-04-07 16:22:43,988: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  25%|██▌       | 253/1000 [1:26:31<4:26:54, 21.44s/it]2025-04-07 16:23:03,452: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  25%|██▌       | 254/1000 [1:26:54<4:32:40, 21.93s/it]2025-04-07 16:23:26,067: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  26%|██▌       | 255/1000 [1:27:20<4:48:30, 23.24s/it]2025-04-07 16:23:52,475: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  26%|██▌       | 256/1000 [1:27:46<4:57:59, 24.03s/it]2025-04-07 16:24:18,046: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  26%|██▌       | 257/1000 [1:28:02<4:26:13, 21.50s/it]2025-04-07 16:24:33,632: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  26%|██▌       | 258/1000 [1:28:20<4:12:22, 20.41s/it]2025-04-07 16:24:51,484: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  26%|██▌       | 259/1000 [1:28:36<3:56:12, 19.13s/it]2025-04-07 16:25:07,807: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  26%|██▌       | 260/1000 [1:28:53<3:48:43, 18.55s/it]2025-04-07 16:25:24,817: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  26%|██▌       | 261/1000 [1:29:18<4:12:14, 20.48s/it]2025-04-07 16:25:49,823: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  26%|██▌       | 262/1000 [1:29:38<4:09:15, 20.26s/it]2025-04-07 16:26:09,763: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  26%|██▋       | 263/1000 [1:29:49<3:37:24, 17.70s/it]2025-04-07 16:26:21,294: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# ...
# Classifying Logical Fallacies:  91%|█████████▏| 913/1000 [5:21:12<30:17, 20.89s/it]2025-04-07 20:17:44,037: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  91%|█████████▏| 914/1000 [5:21:27<27:13, 19.00s/it]2025-04-07 20:17:58,775: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  92%|█████████▏| 915/1000 [5:21:47<27:24, 19.34s/it]2025-04-07 20:18:18,930: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  92%|█████████▏| 916/1000 [5:22:05<26:38, 19.03s/it]2025-04-07 20:18:36,920: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  92%|█████████▏| 917/1000 [5:22:18<23:41, 17.12s/it]2025-04-07 20:18:49,899: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  92%|█████████▏| 918/1000 [5:22:38<24:49, 18.16s/it]2025-04-07 20:19:10,332: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  92%|█████████▏| 919/1000 [5:22:58<25:16, 18.72s/it]2025-04-07 20:19:30,812: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  92%|█████████▏| 920/1000 [5:23:06<20:41, 15.51s/it]2025-04-07 20:19:38,239: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  92%|█████████▏| 921/1000 [5:23:24<21:18, 16.18s/it]2025-04-07 20:19:56,128: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  92%|█████████▏| 922/1000 [5:23:43<22:14, 17.10s/it]2025-04-07 20:20:15,229: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  92%|█████████▏| 923/1000 [5:24:01<22:05, 17.21s/it]2025-04-07 20:20:32,693: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  92%|█████████▏| 924/1000 [5:24:15<20:30, 16.19s/it]2025-04-07 20:20:46,486: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  92%|█████████▎| 925/1000 [5:24:30<19:46, 15.82s/it]2025-04-07 20:21:01,450: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  93%|█████████▎| 926/1000 [5:24:42<18:24, 14.93s/it]2025-04-07 20:21:14,291: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  93%|█████████▎| 927/1000 [5:25:04<20:25, 16.79s/it]2025-04-07 20:21:35,586: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  93%|█████████▎| 928/1000 [5:25:35<25:22, 21.14s/it]2025-04-07 20:22:07,041: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  93%|█████████▎| 929/1000 [5:25:46<21:35, 18.25s/it]2025-04-07 20:22:18,396: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  93%|█████████▎| 930/1000 [5:26:06<21:49, 18.71s/it]2025-04-07 20:22:38,199: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  93%|█████████▎| 931/1000 [5:26:21<20:14, 17.60s/it]2025-04-07 20:22:53,329: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  93%|█████████▎| 932/1000 [5:26:49<23:30, 20.74s/it]2025-04-07 20:23:21,398: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  93%|█████████▎| 933/1000 [5:27:10<23:03, 20.65s/it]2025-04-07 20:23:41,542: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  93%|█████████▎| 934/1000 [5:27:36<24:42, 22.46s/it]2025-04-07 20:24:08,233: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  94%|█████████▎| 935/1000 [5:27:49<21:03, 19.44s/it]2025-04-07 20:24:20,621: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  94%|█████████▎| 936/1000 [5:28:22<25:00, 23.44s/it]2025-04-07 20:24:53,847: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  94%|█████████▎| 937/1000 [5:29:05<30:47, 29.33s/it]2025-04-07 20:25:36,778: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  94%|█████████▍| 938/1000 [5:29:30<29:00, 28.07s/it]2025-04-07 20:26:01,600: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  94%|█████████▍| 939/1000 [5:29:42<23:46, 23.39s/it]2025-04-07 20:26:14,525: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  94%|█████████▍| 940/1000 [5:30:14<26:00, 26.01s/it]2025-04-07 20:26:46,346: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  94%|█████████▍| 941/1000 [5:30:33<23:18, 23.71s/it]2025-04-07 20:27:04,687: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  94%|█████████▍| 942/1000 [5:30:55<22:35, 23.37s/it]2025-04-07 20:27:27,111: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  94%|█████████▍| 943/1000 [5:31:17<21:43, 22.86s/it]2025-04-07 20:27:48,954: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  94%|█████████▍| 944/1000 [5:31:40<21:29, 23.03s/it]2025-04-07 20:28:12,381: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  94%|█████████▍| 945/1000 [5:31:59<20:02, 21.86s/it]2025-04-07 20:28:31,491: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  95%|█████████▍| 946/1000 [5:32:20<19:13, 21.37s/it]2025-04-07 20:28:51,564: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  95%|█████████▍| 947/1000 [5:32:47<20:28, 23.17s/it]2025-04-07 20:29:19,557: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  95%|█████████▍| 948/1000 [5:33:08<19:26, 22.43s/it]2025-04-07 20:29:39,921: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  95%|█████████▍| 949/1000 [5:33:35<20:17, 23.88s/it]2025-04-07 20:30:06,885: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  95%|█████████▌| 950/1000 [5:34:01<20:23, 24.48s/it]2025-04-07 20:30:32,773: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  95%|█████████▌| 951/1000 [5:34:14<17:06, 20.95s/it]2025-04-07 20:30:45,482: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  95%|█████████▌| 952/1000 [5:34:32<16:03, 20.06s/it]2025-04-07 20:31:03,482: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  95%|█████████▌| 953/1000 [5:34:51<15:37, 19.94s/it]2025-04-07 20:31:23,270: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  95%|█████████▌| 954/1000 [5:35:08<14:29, 18.89s/it]2025-04-07 20:31:39,732: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  96%|█████████▌| 955/1000 [5:35:25<13:50, 18.46s/it]2025-04-07 20:31:57,346: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  96%|█████████▌| 956/1000 [5:35:46<14:04, 19.19s/it]2025-04-07 20:32:17,897: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  96%|█████████▌| 957/1000 [5:36:00<12:33, 17.53s/it]2025-04-07 20:32:31,740: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  96%|█████████▌| 958/1000 [5:36:24<13:39, 19.51s/it]2025-04-07 20:32:55,846: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  96%|█████████▌| 959/1000 [5:36:47<14:00, 20.49s/it]2025-04-07 20:33:18,779: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  96%|█████████▌| 960/1000 [5:37:12<14:40, 22.01s/it]2025-04-07 20:33:44,048: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  96%|█████████▌| 961/1000 [5:37:34<14:15, 21.95s/it]2025-04-07 20:34:05,765: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  96%|█████████▌| 962/1000 [5:37:53<13:24, 21.18s/it]2025-04-07 20:34:25,245: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  96%|█████████▋| 963/1000 [5:38:16<13:23, 21.73s/it]2025-04-07 20:34:48,390: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  96%|█████████▋| 964/1000 [5:38:32<11:56, 19.91s/it]2025-04-07 20:35:03,938: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  96%|█████████▋| 965/1000 [5:38:49<11:04, 18.98s/it]2025-04-07 20:35:20,881: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  97%|█████████▋| 966/1000 [5:39:06<10:31, 18.58s/it]2025-04-07 20:35:38,522: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  97%|█████████▋| 967/1000 [5:39:43<13:14, 24.07s/it]2025-04-07 20:36:15,542: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  97%|█████████▋| 968/1000 [5:40:05<12:29, 23.42s/it]2025-04-07 20:36:37,130: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  97%|█████████▋| 969/1000 [5:40:16<10:06, 19.58s/it]2025-04-07 20:36:47,914: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  97%|█████████▋| 970/1000 [5:40:37<09:58, 19.94s/it]2025-04-07 20:37:09,039: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  97%|█████████▋| 971/1000 [5:40:53<09:06, 18.84s/it]2025-04-07 20:37:24,836: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  97%|█████████▋| 972/1000 [5:41:08<08:19, 17.83s/it]2025-04-07 20:37:40,475: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  97%|█████████▋| 973/1000 [5:41:34<09:03, 20.14s/it]2025-04-07 20:38:05,844: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  97%|█████████▋| 974/1000 [5:41:54<08:42, 20.11s/it]2025-04-07 20:38:26,014: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  98%|█████████▊| 975/1000 [5:42:14<08:23, 20.16s/it]2025-04-07 20:38:46,420: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  98%|█████████▊| 976/1000 [5:42:37<08:22, 20.92s/it]2025-04-07 20:39:09,144: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  98%|█████████▊| 977/1000 [5:43:04<08:45, 22.84s/it]2025-04-07 20:39:36,449: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  98%|█████████▊| 978/1000 [5:43:28<08:29, 23.14s/it]2025-04-07 20:39:59,986: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  98%|█████████▊| 979/1000 [5:43:53<08:18, 23.76s/it]2025-04-07 20:40:25,391: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  98%|█████████▊| 980/1000 [5:44:12<07:23, 22.17s/it]2025-04-07 20:40:43,954: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  98%|█████████▊| 981/1000 [5:44:35<07:05, 22.39s/it]2025-04-07 20:41:06,562: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  98%|█████████▊| 982/1000 [5:44:53<06:20, 21.15s/it]2025-04-07 20:41:25,119: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  98%|█████████▊| 983/1000 [5:45:15<06:05, 21.48s/it]2025-04-07 20:41:47,062: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  98%|█████████▊| 984/1000 [5:45:33<05:24, 20.26s/it]2025-04-07 20:42:04,644: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  98%|█████████▊| 985/1000 [5:45:56<05:16, 21.11s/it]2025-04-07 20:42:28,167: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  99%|█████████▊| 986/1000 [5:46:31<05:53, 25.23s/it]2025-04-07 20:43:02,889: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  99%|█████████▊| 987/1000 [5:46:49<05:00, 23.09s/it]2025-04-07 20:43:20,664: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  99%|█████████▉| 988/1000 [5:47:09<04:27, 22.31s/it]2025-04-07 20:43:41,314: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  99%|█████████▉| 989/1000 [5:47:27<03:50, 20.92s/it]2025-04-07 20:43:58,698: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  99%|█████████▉| 990/1000 [5:47:39<03:04, 18.44s/it]2025-04-07 20:44:11,502: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  99%|█████████▉| 991/1000 [5:48:08<03:14, 21.60s/it]2025-04-07 20:44:40,606: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  99%|█████████▉| 992/1000 [5:48:33<02:59, 22.38s/it]2025-04-07 20:45:04,974: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  99%|█████████▉| 993/1000 [5:48:48<02:22, 20.31s/it]2025-04-07 20:45:20,130: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  99%|█████████▉| 994/1000 [5:49:06<01:58, 19.69s/it]2025-04-07 20:45:38,396: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies: 100%|█████████▉| 995/1000 [5:49:25<01:36, 19.33s/it]2025-04-07 20:45:57,018: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies: 100%|█████████▉| 996/1000 [5:49:44<01:17, 19.30s/it]2025-04-07 20:46:16,106: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies: 100%|█████████▉| 997/1000 [5:50:04<00:58, 19.49s/it]2025-04-07 20:46:36,041: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies: 100%|█████████▉| 998/1000 [5:50:34<00:45, 22.77s/it]2025-04-07 20:47:06,507: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies: 100%|█████████▉| 999/1000 [5:50:51<00:20, 20.95s/it]2025-04-07 20:47:23,021: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies: 100%|██████████| 1000/1000 [5:51:06<00:00, 21.07s/it]

# %% [markdown]
# ### Evaluation

# %%
y_true = processed_df["logical_fallacies"] 
y_pred = processed_df["predicted_fallacy"]

# %%
def get_metrics(y_true, y_pred):
    logger.info('classification_report')
    classification_report_dict = classification_report(y_true, y_pred, output_dict=True)
    print(classification_report(y_true, y_pred))

    logger.info('confusion_matrix')
    print(confusion_matrix(y_true, y_pred))

    return classification_report_dict

# %%
def log_metrics(cr):
    for key, value in cr.items():
        if key == "accuracy":
            mlflow.log_metric(key, value)  # Logging accuracy directly
        else:
            for metric in value:
                mlflow.log_metric(f"{key}_{metric}", value.get(metric))  # Logging other metrics

# %%
# note, results have error, need to remove
logger.info('predictions')

classification_report = get_metrics(y_true, y_pred)
log_metrics(classification_report)
# Out:
# 2025-04-07 20:50:59,911: predictions
# 2025-04-07 20:50:59,912: classification_report
# 2025-04-07 20:50:59,956: confusion_matrix
#                        precision    recall  f1-score   support
#
#            ad_hominem       0.70      0.48      0.57        82
#   appeal_to_authority       0.57      0.29      0.38        70
#     appeal_to_emotion       0.28      0.15      0.19       136
#                 error       0.00      0.00      0.00         0
#         false_dilemma       0.55      0.62      0.58        86
# faulty_generalization       0.36      0.61      0.46       131
#                  none       0.63      0.63      0.63       495
#
#              accuracy                           0.53      1000
#             macro avg       0.44      0.40      0.40      1000
#          weighted avg       0.54      0.53      0.52      1000
#
# [[ 39   2   5   1   1  11  23]
#  [  1  20   6   3   2   6  32]
#  [  2   2  20   4   6  19  83]
#  [  0   0   0   0   0   0   0]
#  [  0   0   7   1  53   8  17]
#  [  0   2   8   3   6  80  32]
#  [ 14   9  25  10  28  96 313]]

# %%
mlflow.end_run()
# Out:
# 🏃 View run deepseek-r1:8b at: http://127.0.0.1:5001/#/experiments/823412171152425451/runs/ec2ca99970f943daac67b393bdd123e7
# 🧪 View experiment at: http://127.0.0.1:5001/#/experiments/823412171152425451

# %% [markdown]
# ### Save CSV

# %%
processed_df.to_csv(SAVE_PATH, index=False)

# %% [markdown]
# ### Open CSV

# %%
df_wp = pd.read_csv(SAVE_PATH)

# %%
df_wp_woe = df_wp[df_wp["predicted_fallacy"] != "error"]

# %%
y_true_reload = df_wp_woe["logical_fallacies"] 
y_pred_reload = df_wp_woe["predicted_fallacy"]

# %%
# note, results have error, need to remove
logger.info('predictions')

classification_report = get_metrics(y_true_reload, y_pred_reload)
log_metrics(classification_report)
# Out:
# 2025-04-09 16:20:22,620: predictions
# 2025-04-09 16:20:22,622: classification_report
# 2025-04-09 16:20:22,651: confusion_matrix
#                        precision    recall  f1-score   support
#
#            ad_hominem       0.70      0.48      0.57        81
#   appeal_to_authority       0.57      0.30      0.39        67
#     appeal_to_emotion       0.28      0.15      0.20       132
#         false_dilemma       0.55      0.62      0.59        85
# faulty_generalization       0.36      0.62      0.46       128
#                  none       0.63      0.65      0.64       485
#
#              accuracy                           0.54       978
#             macro avg       0.52      0.47      0.47       978
#          weighted avg       0.54      0.54      0.53       978
#
# [[ 39   2   5   1  11  23]
#  [  1  20   6   2   6  32]
#  [  2   2  20   6  19  83]
#  [  0   0   7  53   8  17]
#  [  0   2   8   6  80  32]
#  [ 14   9  25  28  96 313]]
