# %% [markdown]
# # Zero shot using LLM with Ollama locally

# %% [markdown]
# ### Import necessary packages

# %% [markdown]
# Before coding, you need to do this in your terminal:
# 1. brew install ollama (install ollama framework for starting LLMs locally)
# 2. pip install langchain-ollama (in virtual environment)
# 2. ollama serve (start ollama server)
# 3. get model name from: https://ollama.com/library/
# 4. ollama run name_of_model_from_ollama (e.g. llama3.1:8b; in second terminal; downloads model and runs it)

# %%
import pandas as pd
import os
from tqdm import tqdm
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

import warnings
warnings.filterwarnings("ignore")

from langchain_groq import ChatGroq
from langchain_ollama import OllamaLLM
import warnings
warnings.filterwarnings("ignore")

import mlflow
from mlflow.sklearn import save_model
from mlflow.transformers import log_model
import logging

import config

# %% [markdown]
# ### Setup

# %%
MODEL_NAME = "deepseek" 
TRACKING_URI = open("../.mlflow_uri").read().strip()
EXPERIMENT_NAME = config.EXPERIMENT_NAME

logging.basicConfig(format="%(asctime)s: %(message)s") # Configure logging format to show timestamp before every message

logger = logging.getLogger()
logger.setLevel(logging.INFO) # Only show logs that are INFO or more important (e.g., WARNING, ERROR) — but ignore DEBUG.

# %%
DATA_PATH = "../data/data_val.csv"
SAVE_PATH = "../models/DeepSeek"

# %% [markdown]
# ### Get data

# %%
df = pd.read_csv(DATA_PATH)

# %% [markdown]
# ### Initialize local model using Ollama

# %%
#temperature is hyperparameter, how creative do I want the llm to be (0 is not creative), sometimes, when it is not 0, it can give you the second likely word

# Initialize the local Llama model using Ollama
llm = OllamaLLM(
    model="deepseek-r1:8b",  # llama3.1:8b, Replace with your desired local Llama model version
    # temperature=0,        # no randomness, deterministic output
    max_tokens=None,      # unlimited token length (adjust as needed)
)

# %%
params = {
      #"temperature": 0,
      "max_tokens": None,
  }
  
# setting the MLFlow connection and experiment
mlflow.set_tracking_uri(TRACKING_URI)
mlflow.set_experiment(EXPERIMENT_NAME)

mlflow.start_run()
run = mlflow.active_run()
print("Active run_id: {}".format(run.info.run_id))

mlflow.set_tag("model_name", MODEL_NAME)
mlflow.set_tag('mlflow.runName', 'deepseek-r1:8b')
mlflow.log_params(params)
# Out:
# Active run_id: 150fd5732ad44440a0a254ba5e74b478

# %% [markdown]
# ### Define a prompt

# %%
# import re


# def classify_fallacy(text: str) -> str:
#     """Classifies text into one of the predefined logical fallacies."""
#     try:
#         prompt = f"""Classify the text below into exactly one logical fallacy category:
# - faulty_generalization
# - ad_hominem
# - false_dilemma 
# - appeal_to_authority
# - appeal_to_emotion  
# - none

# **Rules**:
# - Use ONLY the exact category names above
# - If no fallacy matches, use "none"
# - No explanations, only the category name

# Here are definitions of each category for reference:
# 1. **Faulty Generalization**: This fallacy occurs when an argument assumes something is true for a large population without having a large enough sample. A kind of overgeneralization.
# 2. **Ad Hominem**: This fallacy occurs when the speaker is attacking the other person or some aspect of them rather than addressing the argument itself.
# 3. **False Dilemma**: This fallacy occurs when only two options are presented in an argument, even though more options may exist. A case of “either this or that”.
# 4. **Appeal to Authority**: This fallacy occurs when an argument relies on the opinion or endorsement of an authority figure who may not have relevant expertise or whose expertise is questionable.
# 5. **Appeal to Emotion**: This fallacy occurs when emotion is used to support an argument, such as pity, fear, anger, etc.
# 6. **None**: There are no fallacies in this text!

# Here are examples of each category for reference:
# 1. **Faulty Generalization**: "I read one report about corruption, so that industry must be corrupt."
# 2. **Ad Hominem**: "Do you even know what you're talking about?"
# 3. **False Dilemma**: "Do you recommend drinking or injecting bleach to fight Covid?"
# 4. **Appeal to Authority**: "Trust me, I am a lawyer, so I know how to handle your taxes."
# 5. **Appeal to Emotion**: "You murdered 100,000 people, called Coronavirus a hoax, fired doctors, and told Americans to inject themselves with bleach. Maybe you should shut the fuck up."
# 6. **None**: "I don't think that kind of logic is good. It's essentially saying that so long as the authoritarians repress their people enough and nobody can rise up against them, we should think things are okay. We should strive to ensure they have leaders who value democracy, not oppression and authoritarianism."

# Text to classify: {text}

# ."""

#         # Generate response using the local Llama model
#         response = llm.invoke(prompt)
        
#         # for deepseek, remove <think>...</think> tags
#         # Remove <think>...</think> tags and line breaks
#         response = re.sub(r"<think>.*?</think>", "", response, flags=re.DOTALL).strip()

#         # Extract and normalize response content
#         prediction = response.strip().lower()
#         valid_categories = ["faulty_generalization", "ad_hominem", "false_dilemma", 
#                             "appeal_to_authority", "appeal_to_emotion", "none"]
        
#         return prediction if prediction in valid_categories else "error" #else "none"
        
#     except Exception as e:
#         print(f"Error processing text: {text[:50]}... | Error: {str(e)}")
#         return "error"

# %%
#Prompt without faulty generalization, but with slippery slope
import re


def classify_fallacy(text: str) -> str:
    """Classifies text into one of the predefined logical fallacies."""
    try:
        prompt = f"""Classify the text below into exactly one logical fallacy category:
- slippery_slope
- ad_hominem
- false_dilemma 
- appeal_to_authority
- appeal_to_emotion  
- none

**Rules**:
- Use ONLY the exact category names above
- If no fallacy matches, use "none"
- No explanations, only the category name

Here are definitions of each category for reference:
1. **Slippery Slope**: This fallacy occurs when an argument suggests that a relatively minor initial action or event will lead to a chain of increasingly significant and undesirable consequences, often without sufficient evidence to support the causal connections between steps.
2. **Ad Hominem**: This fallacy occurs when the speaker is attacking the other person or some aspect of them rather than addressing the argument itself.
3. **False Dilemma**: This fallacy occurs when only two options are presented in an argument, even though more options may exist. A case of “either this or that”.
4. **Appeal to Authority**: This fallacy occurs when an argument relies on the opinion or endorsement of an authority figure who may not have relevant expertise or whose expertise is questionable.
5. **Appeal to Emotion**: This fallacy occurs when emotion is used to support an argument, such as pity, fear, anger, etc.
6. **None**: There are no fallacies in this text!

Here are examples of each category for reference:
1. **Slippery Slope**: "If we lower the voting age to 17, then people will argue for lowering it to 16, and eventually, babies will be voting."
2. **Ad Hominem**: "Do you even know what you're talking about?"
3. **False Dilemma**: "Do you recommend drinking or injecting bleach to fight Covid?"
4. **Appeal to Authority**: "Trust me, I am a lawyer, so I know how to handle your taxes."
5. **Appeal to Emotion**: "You murdered 100,000 people, called Coronavirus a hoax, fired doctors, and told Americans to inject themselves with bleach. Maybe you should shut the fuck up."
6. **None**: "I don't think that kind of logic is good. It's essentially saying that so long as the authoritarians repress their people enough and nobody can rise up against them, we should think things are okay. We should strive to ensure they have leaders who value democracy, not oppression and authoritarianism."

Text to classify: {text}

."""

        # Generate response using the local Llama model
        response = llm.invoke(prompt)
        
        # for deepseek, remove <think>...</think> tags
        # Remove <think>...</think> tags and line breaks
        response = re.sub(r"<think>.*?</think>", "", response, flags=re.DOTALL).strip()

        # Extract and normalize response content
        prediction = response.strip().lower()
        valid_categories = ["slippery_slope", "ad_hominem", "false_dilemma", 
                            "appeal_to_authority", "appeal_to_emotion", "none"]
        
        return prediction if prediction in valid_categories else "error" #else "none"
        
    except Exception as e:
        print(f"Error processing text: {text[:50]}... | Error: {str(e)}")
        return "error"

# %% [markdown]
# ### Process dataframe

# %%
def process_dataframe(df: pd.DataFrame, batch_size=10) -> pd.DataFrame:
    """Process DataFrame with chunking for better performance."""
    result_df = df.copy()
    
    # Process in smaller batches to reduce errors
    chunks = [df[i:i+batch_size] for i in range(0, len(df), batch_size)]
    
    with tqdm(total=len(df), desc="Classifying Logical Fallacies") as pbar: #tqdm progresses bar
        for chunk in chunks:
            chunk_results = []
            for text in chunk['text']:
                result = classify_fallacy(text)
                chunk_results.append(result)
                pbar.update(1)
                
            # Update results for this chunk
            result_df.loc[chunk.index, 'predicted_fallacy'] = chunk_results
    
    return result_df

# %% [markdown]
# ### Make predictions

# %%
logger.info('prediction of logical fallacies')
# Process the DataFrame and classify logical fallacies
processed_df = process_dataframe(df)
# Out:
# 2025-04-12 12:51:41,579: prediction of logical fallacies
# Classifying Logical Fallacies:   0%|          | 0/1350 [00:00<?, ?it/s]2025-04-12 12:51:45,938: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   0%|          | 1/1350 [00:24<9:13:45, 24.63s/it]2025-04-12 12:52:06,737: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   0%|          | 2/1350 [00:41<7:29:57, 20.03s/it]2025-04-12 12:52:23,391: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   0%|          | 3/1350 [01:05<8:05:58, 21.65s/it]2025-04-12 12:52:47,254: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   0%|          | 4/1350 [01:25<7:54:38, 21.16s/it]2025-04-12 12:53:07,379: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   0%|          | 5/1350 [01:37<6:38:07, 17.76s/it]2025-04-12 12:53:18,959: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   0%|          | 6/1350 [01:56<6:49:14, 18.27s/it]2025-04-12 12:53:38,510: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   1%|          | 7/1350 [02:12<6:32:10, 17.52s/it]2025-04-12 12:53:54,200: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   1%|          | 8/1350 [02:27<6:14:06, 16.73s/it]2025-04-12 12:54:09,371: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   1%|          | 9/1350 [02:44<6:16:35, 16.85s/it]2025-04-12 12:54:26,495: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   1%|          | 10/1350 [03:01<6:16:39, 16.87s/it]2025-04-12 12:54:43,250: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   1%|          | 11/1350 [03:14<5:48:20, 15.61s/it]2025-04-12 12:54:56,156: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   1%|          | 12/1350 [03:31<6:02:25, 16.25s/it]2025-04-12 12:55:14,032: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   1%|          | 13/1350 [03:56<6:55:57, 18.67s/it]2025-04-12 12:55:37,942: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   1%|          | 14/1350 [04:10<6:29:39, 17.50s/it]2025-04-12 12:55:52,746: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   1%|          | 15/1350 [04:23<5:58:04, 16.09s/it]2025-04-12 12:56:05,578: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   1%|          | 16/1350 [05:04<8:43:18, 23.54s/it]2025-04-12 12:56:46,552: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   1%|▏         | 17/1350 [05:18<7:40:35, 20.73s/it]2025-04-12 12:57:00,906: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   1%|▏         | 18/1350 [05:31<6:45:58, 18.29s/it]2025-04-12 12:57:13,360: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   1%|▏         | 19/1350 [05:50<6:50:43, 18.51s/it]2025-04-12 12:57:32,410: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   1%|▏         | 20/1350 [06:14<7:25:22, 20.09s/it]2025-04-12 12:57:56,024: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   2%|▏         | 21/1350 [06:27<6:37:39, 17.95s/it]2025-04-12 12:58:09,137: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   2%|▏         | 22/1350 [06:53<7:32:09, 20.43s/it]2025-04-12 12:58:35,195: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   2%|▏         | 23/1350 [07:20<8:13:43, 22.32s/it]2025-04-12 12:59:02,224: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   2%|▏         | 24/1350 [07:37<7:42:33, 20.93s/it]2025-04-12 12:59:19,609: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   2%|▏         | 25/1350 [07:59<7:50:11, 21.29s/it]2025-04-12 12:59:41,913: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   2%|▏         | 26/1350 [08:13<6:58:26, 18.96s/it]2025-04-12 12:59:55,430: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   2%|▏         | 27/1350 [08:23<5:58:29, 16.26s/it]2025-04-12 13:00:05,228: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   2%|▏         | 28/1350 [08:43<6:22:39, 17.37s/it]2025-04-12 13:00:25,331: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   2%|▏         | 29/1350 [09:04<6:49:47, 18.61s/it]2025-04-12 13:00:46,849: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   2%|▏         | 30/1350 [09:45<9:14:06, 25.19s/it]2025-04-12 13:01:27,254: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   2%|▏         | 31/1350 [10:01<8:12:22, 22.40s/it]2025-04-12 13:01:43,704: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   2%|▏         | 32/1350 [10:42<10:18:58, 28.18s/it]2025-04-12 13:02:24,776: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   2%|▏         | 33/1350 [11:00<9:06:15, 24.89s/it] 2025-04-12 13:02:42,281: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   3%|▎         | 34/1350 [11:14<7:58:58, 21.84s/it]2025-04-12 13:02:57,010: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   3%|▎         | 35/1350 [11:33<7:35:22, 20.78s/it]2025-04-12 13:03:15,019: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   3%|▎         | 36/1350 [11:51<7:16:23, 19.93s/it]2025-04-12 13:03:33,110: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   3%|▎         | 37/1350 [12:05<6:39:53, 18.27s/it]2025-04-12 13:03:47,534: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   3%|▎         | 38/1350 [12:30<7:24:11, 20.31s/it]2025-04-12 13:04:12,606: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   3%|▎         | 39/1350 [12:53<7:38:24, 20.98s/it]2025-04-12 13:04:35,132: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   3%|▎         | 40/1350 [13:22<8:31:18, 23.42s/it]2025-04-12 13:05:04,248: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   3%|▎         | 41/1350 [13:55<9:36:42, 26.43s/it]2025-04-12 13:05:37,557: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   3%|▎         | 42/1350 [14:16<9:01:28, 24.84s/it]2025-04-12 13:05:58,833: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   3%|▎         | 43/1350 [14:30<7:45:51, 21.39s/it]2025-04-12 13:06:12,014: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   3%|▎         | 44/1350 [14:39<6:25:30, 17.71s/it]2025-04-12 13:06:21,136: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   3%|▎         | 45/1350 [14:50<5:44:25, 15.84s/it]2025-04-12 13:06:32,748: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   3%|▎         | 46/1350 [15:13<6:31:06, 18.00s/it]2025-04-12 13:06:55,801: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   3%|▎         | 47/1350 [15:23<5:36:51, 15.51s/it]2025-04-12 13:07:05,501: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   4%|▎         | 48/1350 [15:36<5:18:39, 14.68s/it]2025-04-12 13:07:18,413: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   4%|▎         | 49/1350 [15:46<4:47:35, 13.26s/it]2025-04-12 13:07:28,202: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   4%|▎         | 50/1350 [16:02<5:09:48, 14.30s/it]2025-04-12 13:07:44,926: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   4%|▍         | 51/1350 [16:22<5:46:03, 15.98s/it]2025-04-12 13:08:04,986: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   4%|▍         | 52/1350 [16:39<5:47:18, 16.05s/it]2025-04-12 13:08:21,064: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   4%|▍         | 53/1350 [16:58<6:10:11, 17.13s/it]2025-04-12 13:08:41,128: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   4%|▍         | 54/1350 [17:31<7:53:09, 21.91s/it]2025-04-12 13:09:13,598: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   4%|▍         | 55/1350 [17:53<7:48:25, 21.70s/it]2025-04-12 13:09:34,819: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   4%|▍         | 56/1350 [18:05<6:48:44, 18.95s/it]2025-04-12 13:09:47,355: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   4%|▍         | 57/1350 [18:17<6:00:31, 16.73s/it]2025-04-12 13:09:59,349: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   4%|▍         | 58/1350 [18:36<6:14:21, 17.39s/it]2025-04-12 13:10:17,987: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   4%|▍         | 59/1350 [18:47<5:35:48, 15.61s/it]2025-04-12 13:10:29,574: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   4%|▍         | 60/1350 [19:00<5:19:54, 14.88s/it]2025-04-12 13:10:42,762: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   5%|▍         | 61/1350 [19:20<5:50:34, 16.32s/it]2025-04-12 13:11:02,755: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   5%|▍         | 62/1350 [19:45<6:50:11, 19.11s/it]2025-04-12 13:11:28,641: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   5%|▍         | 63/1350 [20:09<7:16:02, 20.33s/it]2025-04-12 13:11:51,066: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   5%|▍         | 64/1350 [20:42<8:39:27, 24.24s/it]2025-04-12 13:12:24,279: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   5%|▍         | 65/1350 [20:49<6:49:00, 19.10s/it]2025-04-12 13:12:31,678: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   5%|▍         | 66/1350 [21:02<6:11:31, 17.36s/it]2025-04-12 13:12:44,683: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   5%|▍         | 67/1350 [21:14<5:34:18, 15.63s/it]2025-04-12 13:12:56,449: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   5%|▌         | 68/1350 [21:39<6:33:57, 18.44s/it]2025-04-12 13:13:21,425: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   5%|▌         | 69/1350 [21:48<5:34:21, 15.66s/it]2025-04-12 13:13:30,904: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   5%|▌         | 70/1350 [22:24<7:41:47, 21.65s/it]2025-04-12 13:14:06,395: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   5%|▌         | 71/1350 [22:46<7:44:48, 21.81s/it]2025-04-12 13:14:28,397: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   5%|▌         | 72/1350 [23:03<7:15:09, 20.43s/it]2025-04-12 13:14:45,623: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   5%|▌         | 73/1350 [23:43<9:18:01, 26.22s/it]2025-04-12 13:15:25,491: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   5%|▌         | 74/1350 [23:58<8:07:22, 22.92s/it]2025-04-12 13:15:40,555: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   6%|▌         | 75/1350 [24:17<7:43:02, 21.79s/it]2025-04-12 13:15:59,726: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   6%|▌         | 76/1350 [24:29<6:41:28, 18.91s/it]2025-04-12 13:16:11,908: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   6%|▌         | 77/1350 [24:52<7:03:29, 19.96s/it]2025-04-12 13:16:34,316: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   6%|▌         | 78/1350 [25:10<6:53:16, 19.49s/it]2025-04-12 13:16:52,731: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   6%|▌         | 79/1350 [25:37<7:36:04, 21.53s/it]2025-04-12 13:17:19,147: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   6%|▌         | 80/1350 [25:48<6:32:51, 18.56s/it]2025-04-12 13:17:30,485: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   6%|▌         | 81/1350 [26:03<6:06:24, 17.32s/it]2025-04-12 13:17:45,074: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   6%|▌         | 82/1350 [26:18<5:52:59, 16.70s/it]2025-04-12 13:18:00,173: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   6%|▌         | 83/1350 [26:39<6:17:51, 17.89s/it]2025-04-12 13:18:20,898: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   6%|▌         | 84/1350 [26:53<5:53:09, 16.74s/it]2025-04-12 13:18:34,885: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   6%|▋         | 85/1350 [27:19<6:52:11, 19.55s/it]2025-04-12 13:19:01,004: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   6%|▋         | 86/1350 [27:36<6:35:52, 18.79s/it]2025-04-12 13:19:18,318: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   6%|▋         | 87/1350 [28:07<7:55:52, 22.61s/it]2025-04-12 13:19:49,826: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   7%|▋         | 88/1350 [28:27<7:37:44, 21.76s/it]2025-04-12 13:20:09,476: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   7%|▋         | 89/1350 [28:52<7:57:12, 22.71s/it]2025-04-12 13:20:34,261: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   7%|▋         | 90/1350 [29:03<6:46:33, 19.36s/it]2025-04-12 13:20:45,972: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   7%|▋         | 91/1350 [29:25<7:00:22, 20.03s/it]2025-04-12 13:21:07,543: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   7%|▋         | 92/1350 [29:40<6:29:09, 18.56s/it]2025-04-12 13:21:22,680: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   7%|▋         | 93/1350 [30:01<6:40:40, 19.13s/it]2025-04-12 13:21:43,114: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   7%|▋         | 94/1350 [30:19<6:33:10, 18.78s/it]2025-04-12 13:22:01,229: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   7%|▋         | 95/1350 [30:34<6:12:45, 17.82s/it]2025-04-12 13:22:16,668: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   7%|▋         | 96/1350 [30:43<5:18:08, 15.22s/it]2025-04-12 13:22:25,828: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   7%|▋         | 97/1350 [31:06<6:06:09, 17.53s/it]2025-04-12 13:22:48,754: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   7%|▋         | 98/1350 [31:23<5:59:15, 17.22s/it]2025-04-12 13:23:05,368: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   7%|▋         | 99/1350 [31:44<6:22:30, 18.35s/it]2025-04-12 13:23:26,221: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   7%|▋         | 100/1350 [32:02<6:19:30, 18.22s/it]2025-04-12 13:23:44,181: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   7%|▋         | 101/1350 [32:14<5:39:26, 16.31s/it]2025-04-12 13:23:55,825: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   8%|▊         | 102/1350 [32:36<6:16:34, 18.10s/it]2025-04-12 13:24:18,277: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   8%|▊         | 103/1350 [33:12<8:07:25, 23.45s/it]2025-04-12 13:24:54,346: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   8%|▊         | 104/1350 [33:31<7:41:21, 22.22s/it]2025-04-12 13:25:13,549: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   8%|▊         | 105/1350 [33:45<6:48:04, 19.67s/it]2025-04-12 13:25:27,099: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   8%|▊         | 106/1350 [34:18<8:09:09, 23.59s/it]2025-04-12 13:26:00,022: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   8%|▊         | 107/1350 [34:51<9:08:59, 26.50s/it]2025-04-12 13:26:33,317: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   8%|▊         | 108/1350 [35:15<8:52:13, 25.71s/it]2025-04-12 13:26:57,015: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   8%|▊         | 109/1350 [35:26<7:19:42, 21.26s/it]2025-04-12 13:27:07,879: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   8%|▊         | 110/1350 [35:42<6:51:02, 19.89s/it]2025-04-12 13:27:24,577: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   8%|▊         | 111/1350 [36:00<6:38:08, 19.28s/it]2025-04-12 13:27:42,596: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   8%|▊         | 112/1350 [36:15<6:12:45, 18.07s/it]2025-04-12 13:27:57,660: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   8%|▊         | 113/1350 [36:32<6:04:16, 17.67s/it]2025-04-12 13:28:14,712: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   8%|▊         | 114/1350 [36:52<6:16:55, 18.30s/it]2025-04-12 13:28:34,467: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   9%|▊         | 115/1350 [37:10<6:14:43, 18.21s/it]2025-04-12 13:28:52,323: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   9%|▊         | 116/1350 [37:34<6:52:30, 20.06s/it]2025-04-12 13:29:16,689: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   9%|▊         | 117/1350 [37:45<5:55:19, 17.29s/it]2025-04-12 13:29:27,526: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   9%|▊         | 118/1350 [38:01<5:43:58, 16.75s/it]2025-04-12 13:29:42,870: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   9%|▉         | 119/1350 [38:37<7:42:57, 22.56s/it]2025-04-12 13:30:19,295: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   9%|▉         | 120/1350 [38:54<7:08:22, 20.90s/it]2025-04-12 13:30:36,161: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   9%|▉         | 121/1350 [39:12<6:51:52, 20.11s/it]2025-04-12 13:30:54,422: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   9%|▉         | 122/1350 [39:29<6:29:46, 19.04s/it]2025-04-12 13:31:10,827: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   9%|▉         | 123/1350 [39:44<6:09:37, 18.07s/it]2025-04-12 13:31:26,646: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   9%|▉         | 124/1350 [40:02<6:04:59, 17.86s/it]2025-04-12 13:31:44,311: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   9%|▉         | 125/1350 [40:24<6:31:45, 19.19s/it]2025-04-12 13:32:06,285: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   9%|▉         | 126/1350 [40:39<6:08:30, 18.06s/it]2025-04-12 13:32:21,733: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   9%|▉         | 127/1350 [40:52<5:33:14, 16.35s/it]2025-04-12 13:32:34,076: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   9%|▉         | 128/1350 [41:01<4:50:01, 14.24s/it]2025-04-12 13:32:43,398: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  10%|▉         | 129/1350 [41:17<4:57:16, 14.61s/it]2025-04-12 13:32:59,351: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  10%|▉         | 130/1350 [41:31<4:55:04, 14.51s/it]2025-04-12 13:33:13,756: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  10%|▉         | 131/1350 [41:48<5:11:53, 15.35s/it]2025-04-12 13:33:30,626: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  10%|▉         | 132/1350 [42:20<6:54:19, 20.41s/it]2025-04-12 13:34:02,679: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  10%|▉         | 133/1350 [42:33<6:09:07, 18.20s/it]2025-04-12 13:34:15,870: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  10%|▉         | 134/1350 [42:53<6:19:23, 18.72s/it]2025-04-12 13:34:35,811: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  10%|█         | 135/1350 [43:13<6:22:37, 18.90s/it]2025-04-12 13:34:55,114: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  10%|█         | 136/1350 [43:24<5:34:26, 16.53s/it]2025-04-12 13:35:06,121: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  10%|█         | 137/1350 [43:40<5:35:49, 16.61s/it]2025-04-12 13:35:23,072: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  10%|█         | 138/1350 [44:09<6:47:37, 20.18s/it]2025-04-12 13:35:51,275: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  10%|█         | 139/1350 [44:25<6:22:15, 18.94s/it]2025-04-12 13:36:07,474: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  10%|█         | 140/1350 [45:13<9:18:22, 27.69s/it]2025-04-12 13:36:55,419: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  10%|█         | 141/1350 [45:29<8:06:08, 24.13s/it]2025-04-12 13:37:11,234: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  11%|█         | 142/1350 [45:50<7:44:42, 23.08s/it]2025-04-12 13:37:31,885: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  11%|█         | 143/1350 [46:05<6:58:57, 20.83s/it]2025-04-12 13:37:47,600: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  11%|█         | 144/1350 [46:17<6:06:40, 18.24s/it]2025-04-12 13:37:59,815: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  11%|█         | 145/1350 [46:43<6:52:28, 20.54s/it]2025-04-12 13:38:25,857: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  11%|█         | 146/1350 [46:55<5:59:17, 17.90s/it]2025-04-12 13:38:37,764: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  11%|█         | 147/1350 [47:11<5:50:22, 17.48s/it]2025-04-12 13:38:54,377: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  11%|█         | 148/1350 [47:30<5:58:58, 17.92s/it]2025-04-12 13:39:12,743: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  11%|█         | 149/1350 [47:46<5:41:33, 17.06s/it]2025-04-12 13:39:27,808: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  11%|█         | 150/1350 [48:03<5:41:05, 17.05s/it]2025-04-12 13:39:45,152: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  11%|█         | 151/1350 [48:22<5:57:33, 17.89s/it]2025-04-12 13:40:04,872: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  11%|█▏        | 152/1350 [48:41<6:01:11, 18.09s/it]2025-04-12 13:40:23,398: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  11%|█▏        | 153/1350 [49:03<6:26:20, 19.37s/it]2025-04-12 13:40:45,582: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  11%|█▏        | 154/1350 [49:20<6:11:54, 18.66s/it]2025-04-12 13:41:02,742: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  11%|█▏        | 155/1350 [49:53<7:33:24, 22.77s/it]2025-04-12 13:41:35,398: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  12%|█▏        | 156/1350 [50:25<8:30:37, 25.66s/it]2025-04-12 13:42:07,650: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  12%|█▏        | 157/1350 [50:50<8:23:13, 25.31s/it]2025-04-12 13:42:31,840: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  12%|█▏        | 158/1350 [51:04<7:16:19, 21.96s/it]2025-04-12 13:42:46,004: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  12%|█▏        | 159/1350 [51:08<5:33:43, 16.81s/it]2025-04-12 13:42:50,793: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  12%|█▏        | 160/1350 [51:26<5:38:59, 17.09s/it]2025-04-12 13:43:08,697: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  12%|█▏        | 161/1350 [51:45<5:48:34, 17.59s/it]2025-04-12 13:43:27,588: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  12%|█▏        | 162/1350 [52:07<6:13:09, 18.85s/it]2025-04-12 13:43:49,226: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  12%|█▏        | 163/1350 [52:19<5:33:20, 16.85s/it]2025-04-12 13:44:01,707: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  12%|█▏        | 164/1350 [52:38<5:45:36, 17.48s/it]2025-04-12 13:44:20,384: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  12%|█▏        | 165/1350 [52:51<5:17:27, 16.07s/it]2025-04-12 13:44:33,008: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  12%|█▏        | 166/1350 [53:01<4:43:40, 14.38s/it]2025-04-12 13:44:43,415: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  12%|█▏        | 167/1350 [53:18<4:56:50, 15.06s/it]2025-04-12 13:45:00,359: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  12%|█▏        | 168/1350 [53:32<4:50:18, 14.74s/it]2025-04-12 13:45:14,051: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  13%|█▎        | 169/1350 [53:48<4:59:14, 15.20s/it]2025-04-12 13:45:30,501: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  13%|█▎        | 170/1350 [53:57<4:24:46, 13.46s/it]2025-04-12 13:45:40,219: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  13%|█▎        | 171/1350 [54:22<5:30:42, 16.83s/it]2025-04-12 13:46:04,595: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  13%|█▎        | 172/1350 [54:37<5:21:32, 16.38s/it]2025-04-12 13:46:19,904: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  13%|█▎        | 173/1350 [54:57<5:38:32, 17.26s/it]2025-04-12 13:46:39,223: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  13%|█▎        | 174/1350 [55:12<5:26:41, 16.67s/it]2025-04-12 13:46:54,359: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  13%|█▎        | 175/1350 [55:26<5:08:51, 15.77s/it]2025-04-12 13:47:08,187: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  13%|█▎        | 176/1350 [55:55<6:26:48, 19.77s/it]2025-04-12 13:47:37,295: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  13%|█▎        | 177/1350 [56:07<5:39:05, 17.34s/it]2025-04-12 13:47:48,980: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  13%|█▎        | 178/1350 [56:22<5:25:38, 16.67s/it]2025-04-12 13:48:04,074: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  13%|█▎        | 179/1350 [56:44<5:59:10, 18.40s/it]2025-04-12 13:48:26,519: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  13%|█▎        | 180/1350 [57:04<6:05:11, 18.73s/it]2025-04-12 13:48:45,861: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  13%|█▎        | 181/1350 [57:26<6:25:52, 19.81s/it]2025-04-12 13:49:08,180: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  13%|█▎        | 182/1350 [57:42<6:01:25, 18.57s/it]2025-04-12 13:49:23,849: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  14%|█▎        | 183/1350 [57:56<5:39:37, 17.46s/it]2025-04-12 13:49:38,891: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  14%|█▎        | 184/1350 [58:08<5:07:31, 15.82s/it]2025-04-12 13:49:50,887: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  14%|█▎        | 185/1350 [58:19<4:38:46, 14.36s/it]2025-04-12 13:50:01,668: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  14%|█▍        | 186/1350 [58:32<4:26:46, 13.75s/it]2025-04-12 13:50:14,005: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  14%|█▍        | 187/1350 [58:57<5:32:16, 17.14s/it]2025-04-12 13:50:39,072: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  14%|█▍        | 188/1350 [59:16<5:42:04, 17.66s/it]2025-04-12 13:50:57,941: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  14%|█▍        | 189/1350 [59:33<5:38:16, 17.48s/it]2025-04-12 13:51:15,002: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  14%|█▍        | 190/1350 [59:51<5:42:01, 17.69s/it]2025-04-12 13:51:33,347: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  14%|█▍        | 191/1350 [1:00:13<6:06:12, 18.96s/it]2025-04-12 13:51:55,099: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  14%|█▍        | 192/1350 [1:00:32<6:07:39, 19.05s/it]2025-04-12 13:52:14,656: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  14%|█▍        | 193/1350 [1:01:00<6:59:24, 21.75s/it]2025-04-12 13:52:42,567: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  14%|█▍        | 194/1350 [1:01:20<6:49:10, 21.24s/it]2025-04-12 13:53:02,601: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  14%|█▍        | 195/1350 [1:01:51<7:45:40, 24.19s/it]2025-04-12 13:53:33,548: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  15%|█▍        | 196/1350 [1:02:02<6:30:31, 20.30s/it]2025-04-12 13:53:44,915: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  15%|█▍        | 197/1350 [1:02:33<7:27:17, 23.28s/it]2025-04-12 13:54:15,139: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  15%|█▍        | 198/1350 [1:02:55<7:20:56, 22.97s/it]2025-04-12 13:54:37,667: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  15%|█▍        | 199/1350 [1:03:12<6:46:02, 21.17s/it]2025-04-12 13:54:54,192: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  15%|█▍        | 200/1350 [1:03:34<6:51:53, 21.49s/it]2025-04-12 13:55:16,449: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  15%|█▍        | 201/1350 [1:03:55<6:48:57, 21.36s/it]2025-04-12 13:55:37,472: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  15%|█▍        | 202/1350 [1:04:05<5:40:05, 17.77s/it]2025-04-12 13:55:46,890: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  15%|█▌        | 203/1350 [1:04:22<5:35:19, 17.54s/it]2025-04-12 13:56:04,046: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  15%|█▌        | 204/1350 [1:04:33<4:58:51, 15.65s/it]2025-04-12 13:56:15,273: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  15%|█▌        | 205/1350 [1:04:56<5:41:18, 17.89s/it]2025-04-12 13:56:38,224: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  15%|█▌        | 206/1350 [1:05:13<5:34:45, 17.56s/it]2025-04-12 13:56:55,016: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  15%|█▌        | 207/1350 [1:05:31<5:37:50, 17.73s/it]2025-04-12 13:57:13,159: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  15%|█▌        | 208/1350 [1:05:53<6:00:38, 18.95s/it]2025-04-12 13:57:35,242: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  15%|█▌        | 209/1350 [1:06:17<6:33:34, 20.70s/it]2025-04-12 13:57:59,724: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  16%|█▌        | 210/1350 [1:06:35<6:12:51, 19.62s/it]2025-04-12 13:58:17,001: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  16%|█▌        | 211/1350 [1:07:00<6:48:09, 21.50s/it]2025-04-12 13:58:43,023: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  16%|█▌        | 212/1350 [1:07:24<6:58:58, 22.09s/it]2025-04-12 13:59:06,340: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  16%|█▌        | 213/1350 [1:07:45<6:54:23, 21.87s/it]2025-04-12 13:59:27,689: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  16%|█▌        | 214/1350 [1:08:03<6:32:03, 20.71s/it]2025-04-12 13:59:45,531: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  16%|█▌        | 215/1350 [1:08:20<6:07:37, 19.43s/it]2025-04-12 14:00:02,003: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  16%|█▌        | 216/1350 [1:08:40<6:11:37, 19.66s/it]2025-04-12 14:00:22,786: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  16%|█▌        | 217/1350 [1:09:08<6:57:20, 22.10s/it]2025-04-12 14:00:50,573: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  16%|█▌        | 218/1350 [1:09:34<7:18:14, 23.23s/it]2025-04-12 14:01:16,140: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  16%|█▌        | 219/1350 [1:09:53<6:59:02, 22.23s/it]2025-04-12 14:01:36,041: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  16%|█▋        | 220/1350 [1:10:16<6:58:06, 22.20s/it]2025-04-12 14:01:58,041: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  16%|█▋        | 221/1350 [1:10:29<6:06:09, 19.46s/it]2025-04-12 14:02:10,939: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  16%|█▋        | 222/1350 [1:10:49<6:08:09, 19.58s/it]2025-04-12 14:02:31,102: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  17%|█▋        | 223/1350 [1:11:00<5:20:58, 17.09s/it]2025-04-12 14:02:42,084: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  17%|█▋        | 224/1350 [1:12:02<9:32:29, 30.51s/it]2025-04-12 14:03:43,893: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  17%|█▋        | 225/1350 [1:12:17<8:05:46, 25.91s/it]2025-04-12 14:03:59,074: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  17%|█▋        | 226/1350 [1:13:04<10:02:43, 32.17s/it]2025-04-12 14:04:46,042: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  17%|█▋        | 227/1350 [1:13:14<7:57:45, 25.53s/it] 2025-04-12 14:04:56,031: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  17%|█▋        | 228/1350 [1:13:35<7:33:13, 24.24s/it]2025-04-12 14:05:17,270: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  17%|█▋        | 229/1350 [1:13:48<6:32:56, 21.03s/it]2025-04-12 14:05:30,815: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  17%|█▋        | 230/1350 [1:14:15<7:04:06, 22.72s/it]2025-04-12 14:05:57,329: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  17%|█▋        | 231/1350 [1:14:28<6:09:44, 19.83s/it]2025-04-12 14:06:10,396: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  17%|█▋        | 232/1350 [1:14:36<5:05:26, 16.39s/it]2025-04-12 14:06:18,767: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  17%|█▋        | 233/1350 [1:14:50<4:48:17, 15.49s/it]2025-04-12 14:06:32,137: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  17%|█▋        | 234/1350 [1:15:02<4:30:17, 14.53s/it]2025-04-12 14:06:44,598: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  17%|█▋        | 235/1350 [1:15:13<4:09:58, 13.45s/it]2025-04-12 14:06:55,567: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  17%|█▋        | 236/1350 [1:15:43<5:42:20, 18.44s/it]2025-04-12 14:07:25,455: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  18%|█▊        | 237/1350 [1:15:50<4:37:51, 14.98s/it]2025-04-12 14:07:32,508: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  18%|█▊        | 238/1350 [1:16:13<5:22:47, 17.42s/it]2025-04-12 14:07:55,461: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  18%|█▊        | 239/1350 [1:16:31<5:24:58, 17.55s/it]2025-04-12 14:08:13,323: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  18%|█▊        | 240/1350 [1:16:43<4:54:02, 15.89s/it]2025-04-12 14:08:25,363: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  18%|█▊        | 241/1350 [1:16:55<4:33:55, 14.82s/it]2025-04-12 14:08:37,823: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  18%|█▊        | 242/1350 [1:17:13<4:51:04, 15.76s/it]2025-04-12 14:08:55,625: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  18%|█▊        | 243/1350 [1:17:30<4:55:54, 16.04s/it]2025-04-12 14:09:12,607: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  18%|█▊        | 244/1350 [1:17:53<5:31:56, 18.01s/it]2025-04-12 14:09:35,062: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  18%|█▊        | 245/1350 [1:18:03<4:51:49, 15.85s/it]2025-04-12 14:09:45,873: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  18%|█▊        | 246/1350 [1:18:29<5:46:06, 18.81s/it]2025-04-12 14:10:11,481: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  18%|█▊        | 247/1350 [1:18:42<5:13:20, 17.05s/it]2025-04-12 14:10:24,380: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  18%|█▊        | 248/1350 [1:19:01<5:23:46, 17.63s/it]2025-04-12 14:10:43,951: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  18%|█▊        | 249/1350 [1:19:15<5:00:59, 16.40s/it]2025-04-12 14:10:57,056: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  19%|█▊        | 250/1350 [1:19:38<5:37:11, 18.39s/it]2025-04-12 14:11:20,088: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  19%|█▊        | 251/1350 [1:19:52<5:16:46, 17.29s/it]2025-04-12 14:11:34,673: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  19%|█▊        | 252/1350 [1:20:06<4:58:54, 16.33s/it]2025-04-12 14:11:48,718: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  19%|█▊        | 253/1350 [1:20:21<4:48:31, 15.78s/it]2025-04-12 14:12:03,249: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  19%|█▉        | 254/1350 [1:20:39<4:58:25, 16.34s/it]2025-04-12 14:12:20,911: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  19%|█▉        | 255/1350 [1:20:52<4:42:07, 15.46s/it]2025-04-12 14:12:34,233: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  19%|█▉        | 256/1350 [1:21:06<4:33:17, 14.99s/it]2025-04-12 14:12:48,179: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  19%|█▉        | 257/1350 [1:21:20<4:26:11, 14.61s/it]2025-04-12 14:13:02,084: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  19%|█▉        | 258/1350 [1:21:38<4:45:02, 15.66s/it]2025-04-12 14:13:20,192: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  19%|█▉        | 259/1350 [1:21:57<5:04:12, 16.73s/it]2025-04-12 14:13:39,257: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  19%|█▉        | 260/1350 [1:22:14<5:06:58, 16.90s/it]2025-04-12 14:13:56,578: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  19%|█▉        | 261/1350 [1:22:29<4:57:07, 16.37s/it]2025-04-12 14:14:11,847: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  19%|█▉        | 262/1350 [1:22:45<4:50:43, 16.03s/it]2025-04-12 14:14:26,931: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  19%|█▉        | 263/1350 [1:23:08<5:28:44, 18.15s/it]2025-04-12 14:14:50,171: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# ...
# Classifying Logical Fallacies:  94%|█████████▎| 1263/1350 [6:40:26<20:07, 13.87s/it]2025-04-12 19:32:08,429: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  94%|█████████▎| 1264/1350 [6:40:42<20:56, 14.61s/it]2025-04-12 19:32:25,059: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  94%|█████████▎| 1265/1350 [6:40:57<20:33, 14.52s/it]2025-04-12 19:32:39,369: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  94%|█████████▍| 1266/1350 [6:41:14<21:21, 15.26s/it]2025-04-12 19:32:56,211: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  94%|█████████▍| 1267/1350 [6:41:31<21:50, 15.79s/it]2025-04-12 19:33:13,388: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  94%|█████████▍| 1268/1350 [6:41:44<20:39, 15.11s/it]2025-04-12 19:33:26,769: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  94%|█████████▍| 1269/1350 [6:42:11<24:59, 18.52s/it]2025-04-12 19:33:53,369: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  94%|█████████▍| 1270/1350 [6:42:34<26:29, 19.87s/it]2025-04-12 19:34:16,273: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  94%|█████████▍| 1271/1350 [6:42:54<26:13, 19.92s/it]2025-04-12 19:34:36,878: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  94%|█████████▍| 1272/1350 [6:43:14<25:51, 19.89s/it]2025-04-12 19:34:56,124: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  94%|█████████▍| 1273/1350 [6:43:38<27:20, 21.30s/it]2025-04-12 19:35:20,561: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  94%|█████████▍| 1274/1350 [6:43:52<24:13, 19.13s/it]2025-04-12 19:35:35,196: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  94%|█████████▍| 1275/1350 [6:44:17<25:51, 20.69s/it]2025-04-12 19:35:59,092: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  95%|█████████▍| 1276/1350 [6:44:34<24:18, 19.70s/it]2025-04-12 19:36:16,635: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  95%|█████████▍| 1277/1350 [6:45:01<26:40, 21.93s/it]2025-04-12 19:36:43,613: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  95%|█████████▍| 1278/1350 [6:45:13<22:42, 18.92s/it]2025-04-12 19:36:55,526: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  95%|█████████▍| 1279/1350 [6:45:27<20:47, 17.57s/it]2025-04-12 19:37:09,924: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  95%|█████████▍| 1280/1350 [6:45:54<23:45, 20.37s/it]2025-04-12 19:37:36,845: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  95%|█████████▍| 1281/1350 [6:46:13<22:45, 19.79s/it]2025-04-12 19:37:55,127: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  95%|█████████▍| 1282/1350 [6:46:26<20:15, 17.88s/it]2025-04-12 19:38:08,834: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  95%|█████████▌| 1283/1350 [6:46:47<21:01, 18.83s/it]2025-04-12 19:38:29,751: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  95%|█████████▌| 1284/1350 [6:47:13<22:59, 20.90s/it]2025-04-12 19:38:56,067: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  95%|█████████▌| 1285/1350 [6:47:33<22:18, 20.58s/it]2025-04-12 19:39:15,460: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  95%|█████████▌| 1286/1350 [6:47:44<19:01, 17.83s/it]2025-04-12 19:39:27,170: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  95%|█████████▌| 1287/1350 [6:48:08<20:40, 19.69s/it]2025-04-12 19:39:50,760: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  95%|█████████▌| 1288/1350 [6:48:28<20:16, 19.62s/it]2025-04-12 19:40:10,202: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  95%|█████████▌| 1289/1350 [6:48:51<21:06, 20.77s/it]2025-04-12 19:40:33,500: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  96%|█████████▌| 1290/1350 [6:49:09<19:58, 19.98s/it]2025-04-12 19:40:51,952: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  96%|█████████▌| 1291/1350 [6:49:32<20:26, 20.79s/it]2025-04-12 19:41:14,656: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  96%|█████████▌| 1292/1350 [6:49:48<18:49, 19.48s/it]2025-04-12 19:41:31,043: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  96%|█████████▌| 1293/1350 [6:49:59<15:59, 16.83s/it]2025-04-12 19:41:41,984: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  96%|█████████▌| 1294/1350 [6:50:17<15:58, 17.11s/it]2025-04-12 19:41:59,608: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  96%|█████████▌| 1295/1350 [6:50:41<17:41, 19.30s/it]2025-04-12 19:42:23,854: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  96%|█████████▌| 1296/1350 [6:51:00<17:12, 19.13s/it]2025-04-12 19:42:42,577: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  96%|█████████▌| 1297/1350 [6:51:17<16:22, 18.54s/it]2025-04-12 19:42:59,622: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  96%|█████████▌| 1298/1350 [6:51:37<16:18, 18.82s/it]2025-04-12 19:43:18,926: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  96%|█████████▌| 1299/1350 [6:51:49<14:13, 16.74s/it]2025-04-12 19:43:31,400: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  96%|█████████▋| 1300/1350 [6:52:17<16:49, 20.20s/it]2025-04-12 19:43:59,379: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  96%|█████████▋| 1301/1350 [6:52:34<15:39, 19.16s/it]2025-04-12 19:44:16,131: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  96%|█████████▋| 1302/1350 [6:52:48<14:19, 17.90s/it]2025-04-12 19:44:30,929: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  97%|█████████▋| 1303/1350 [6:53:12<15:17, 19.52s/it]2025-04-12 19:44:54,368: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  97%|█████████▋| 1304/1350 [6:53:30<14:39, 19.12s/it]2025-04-12 19:45:12,432: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  97%|█████████▋| 1305/1350 [6:53:42<12:50, 17.11s/it]2025-04-12 19:45:25,157: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  97%|█████████▋| 1306/1350 [6:53:57<12:04, 16.46s/it]2025-04-12 19:45:39,941: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  97%|█████████▋| 1307/1350 [6:54:17<12:28, 17.42s/it]2025-04-12 19:45:59,437: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  97%|█████████▋| 1308/1350 [6:54:37<12:38, 18.06s/it]2025-04-12 19:46:19,155: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  97%|█████████▋| 1309/1350 [6:55:00<13:23, 19.59s/it]2025-04-12 19:46:42,182: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  97%|█████████▋| 1310/1350 [6:55:17<12:31, 18.79s/it]2025-04-12 19:46:58,927: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  97%|█████████▋| 1311/1350 [6:55:37<12:25, 19.12s/it]2025-04-12 19:47:19,110: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  97%|█████████▋| 1312/1350 [6:56:00<12:52, 20.33s/it]2025-04-12 19:47:42,140: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  97%|█████████▋| 1313/1350 [6:56:15<11:32, 18.71s/it]2025-04-12 19:47:57,057: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  97%|█████████▋| 1314/1350 [6:56:41<12:41, 21.16s/it]2025-04-12 19:48:23,792: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  97%|█████████▋| 1315/1350 [6:56:57<11:20, 19.45s/it]2025-04-12 19:48:39,410: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  97%|█████████▋| 1316/1350 [6:57:16<11:00, 19.43s/it]2025-04-12 19:48:58,775: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  98%|█████████▊| 1317/1350 [6:57:26<09:00, 16.36s/it]2025-04-12 19:49:08,136: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  98%|█████████▊| 1318/1350 [6:57:44<09:01, 16.94s/it]2025-04-12 19:49:26,261: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  98%|█████████▊| 1319/1350 [6:57:56<08:04, 15.62s/it]2025-04-12 19:49:38,807: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  98%|█████████▊| 1320/1350 [6:58:12<07:50, 15.70s/it]2025-04-12 19:49:54,715: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  98%|█████████▊| 1321/1350 [6:58:27<07:27, 15.44s/it]2025-04-12 19:50:09,552: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  98%|█████████▊| 1322/1350 [6:58:51<08:20, 17.87s/it]2025-04-12 19:50:33,075: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  98%|█████████▊| 1323/1350 [6:59:06<07:38, 17.00s/it]2025-04-12 19:50:48,031: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  98%|█████████▊| 1324/1350 [6:59:20<07:04, 16.31s/it]2025-04-12 19:51:02,739: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  98%|█████████▊| 1325/1350 [6:59:42<07:26, 17.87s/it]2025-04-12 19:51:24,240: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  98%|█████████▊| 1326/1350 [7:00:03<07:31, 18.82s/it]2025-04-12 19:51:45,431: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  98%|█████████▊| 1327/1350 [7:01:04<12:02, 31.43s/it]2025-04-12 19:52:46,127: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  98%|█████████▊| 1328/1350 [7:01:17<09:32, 26.02s/it]2025-04-12 19:52:59,390: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  98%|█████████▊| 1329/1350 [7:01:34<08:10, 23.35s/it]2025-04-12 19:53:16,810: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  99%|█████████▊| 1330/1350 [7:01:51<07:06, 21.35s/it]2025-04-12 19:53:33,773: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  99%|█████████▊| 1331/1350 [7:02:12<06:46, 21.39s/it]2025-04-12 19:53:54,813: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  99%|█████████▊| 1332/1350 [7:02:32<06:14, 20.83s/it]2025-04-12 19:54:14,333: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  99%|█████████▊| 1333/1350 [7:03:08<07:09, 25.29s/it]2025-04-12 19:54:50,179: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  99%|█████████▉| 1334/1350 [7:03:16<05:25, 20.36s/it]2025-04-12 19:54:59,181: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  99%|█████████▉| 1335/1350 [7:03:44<05:35, 22.39s/it]2025-04-12 19:55:26,026: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  99%|█████████▉| 1336/1350 [7:04:10<05:31, 23.70s/it]2025-04-12 19:55:52,900: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  99%|█████████▉| 1337/1350 [7:04:26<04:34, 21.15s/it]2025-04-12 19:56:07,982: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  99%|█████████▉| 1338/1350 [7:04:45<04:09, 20.76s/it]2025-04-12 19:56:27,975: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  99%|█████████▉| 1339/1350 [7:05:07<03:51, 21.03s/it]2025-04-12 19:56:49,634: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  99%|█████████▉| 1340/1350 [7:05:16<02:55, 17.54s/it]2025-04-12 19:56:59,028: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  99%|█████████▉| 1341/1350 [7:05:40<02:53, 19.33s/it]2025-04-12 19:57:22,704: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  99%|█████████▉| 1342/1350 [7:06:03<02:43, 20.49s/it]2025-04-12 19:57:45,725: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  99%|█████████▉| 1343/1350 [7:06:21<02:18, 19.74s/it]2025-04-12 19:58:03,590: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies: 100%|█████████▉| 1344/1350 [7:06:45<02:05, 20.98s/it]2025-04-12 19:58:27,603: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies: 100%|█████████▉| 1345/1350 [7:07:03<01:39, 19.97s/it]2025-04-12 19:58:45,212: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies: 100%|█████████▉| 1346/1350 [7:07:22<01:18, 19.74s/it]2025-04-12 19:59:04,267: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies: 100%|█████████▉| 1347/1350 [7:07:33<00:51, 17.22s/it]2025-04-12 19:59:15,756: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies: 100%|█████████▉| 1348/1350 [7:07:51<00:34, 17.34s/it]2025-04-12 19:59:33,238: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies: 100%|█████████▉| 1349/1350 [7:08:02<00:15, 15.56s/it]2025-04-12 19:59:44,643: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies: 100%|██████████| 1350/1350 [7:08:15<00:00, 19.03s/it]

# %% [markdown]
# ### Evaluation

# %%
y_true = processed_df["logical_fallacies"] 
y_pred = processed_df["predicted_fallacy"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 y_true = processed_df["logical_fallacies"]
#       2 y_pred = processed_df["predicted_fallacy"]
#
# NameError: name 'processed_df' is not defined

# %%
def get_metrics(y_true, y_pred):
    logger.info('classification_report')
    classification_report_dict = classification_report(y_true, y_pred, output_dict=True)
    print(classification_report(y_true, y_pred))

    logger.info('confusion_matrix')
    print(confusion_matrix(y_true, y_pred))

    return classification_report_dict

# %%
def log_metrics(cr):
    for key, value in cr.items():
        if key == "accuracy":
            mlflow.log_metric(key, value)  # Logging accuracy directly
        else:
            for metric in value:
                mlflow.log_metric(f"{key}_{metric}", value.get(metric))  # Logging other metrics

# %%
# note, results have error, need to remove
logger.info('predictions')

classification_report = get_metrics(y_true, y_pred)
log_metrics(classification_report)
# Out:
# 2025-04-12 19:59:56,684: predictions
# 2025-04-12 19:59:56,684: classification_report
# 2025-04-12 19:59:56,758: confusion_matrix
#                      precision    recall  f1-score   support
#
#          ad_hominem       0.87      0.42      0.56       250
# appeal_to_authority       0.80      0.39      0.53       250
#   appeal_to_emotion       0.52      0.20      0.28       250
#               error       0.00      0.00      0.00         0
#       false_dilemma       0.75      0.60      0.66       250
#                none       0.30      0.78      0.43       250
#      slippery_slope       0.56      0.79      0.65       100
#
#            accuracy                           0.50      1350
#           macro avg       0.54      0.45      0.45      1350
#        weighted avg       0.64      0.50      0.51      1350
#
# [[104  11  16   5  13  97   4]
#  [  4  98   5  11  13 107  12]
#  [  8   2  49   4  11 164  12]
#  [  0   0   0   0   0   0   0]
#  [  1   1   6   3 149  69  21]
#  [  2  10  13   3  13 195  14]
#  [  0   0   5   0   0  16  79]]

# %%
mlflow.end_run()
# Out:
# 🏃 View run deepseek-r1:8b at: http://127.0.0.1:5001/#/experiments/823412171152425451/runs/150fd5732ad44440a0a254ba5e74b478
# 🧪 View experiment at: http://127.0.0.1:5001/#/experiments/823412171152425451

# %% [markdown]
# ### Save CSV

# %%
processed_df.to_csv(SAVE_PATH, index=False)

# %% [markdown]
# ### Open CSV

# %%
df = pd.read_csv(SAVE_PATH)

# %%
df.head()
# Out:
#    dataset                                               text
# 0        3  Either the Prime Minister lets independent med...  \
# 1        3  Turkey really needs to get rid of Erdogan and ...
# 2        3  I understand Turkey s position here They can t...
# 3        3  I don t know why the international community e...
# 4        1  If it is very low for instance around one it m...
#
#   logical_fallacies                                             source
# 0     false_dilemma                                                NaN  \
# 1     false_dilemma                                                NaN
# 2     false_dilemma                                                NaN
# 3     false_dilemma                                                NaN
# 4     false_dilemma  http://business.financialpost.com/opinion/ross...
#
#   two_class_target predicted_fallacy
# 0          fallacy              none
# 1          fallacy              none
# 2          fallacy     false_dilemma
# 3          fallacy              none
# 4          fallacy    slippery_slope

# %%
df_woe = df[df["predicted_fallacy"] != "error"]

# %%
y_true_reload = df_woe["logical_fallacies"] 
y_pred_reload = df_woe["predicted_fallacy"]

# %%
# note, results have error, need to remove
logger.info('predictions')

classification_report = get_metrics(y_true_reload, y_pred_reload)
log_metrics(classification_report)
# Out:
# 2025-04-12 21:58:59,161: predictions
# 2025-04-12 21:58:59,163: classification_report
# 2025-04-12 21:58:59,195: confusion_matrix
#                      precision    recall  f1-score   support
#
#          ad_hominem       0.87      0.42      0.57       245
# appeal_to_authority       0.80      0.41      0.54       239
#   appeal_to_emotion       0.52      0.20      0.29       246
#       false_dilemma       0.75      0.60      0.67       247
#                none       0.30      0.79      0.44       247
#      slippery_slope       0.56      0.79      0.65       100
#
#            accuracy                           0.51      1324
#           macro avg       0.63      0.54      0.53      1324
#        weighted avg       0.64      0.51      0.51      1324
#
# [[104  11  16  13  97   4]
#  [  4  98   5  13 107  12]
#  [  8   2  49  11 164  12]
#  [  1   1   6 149  69  21]
#  [  2  10  13  13 195  14]
#  [  0   0   5   0  16  79]]
