# %% [markdown]
# # Zero shot using LLAMA locally

# %% [markdown]
# ### Import necessary packages

# %% [markdown]
# Before coding, you need to do this in your terminal:
# 1. brew install ollama (install ollama framework for starting LLMs locally)
# 2. pip install langchain-ollama (in virtual environment)
# 2. ollama serve (start ollama server)
# 3. get model name from: https://ollama.com/library/
# 4. ollama run llama3.1:8b (in second terminal; downloads model and runs it)

# %%
import pandas as pd
import os
from tqdm import tqdm
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, classification_report

import warnings
warnings.filterwarnings("ignore")

from langchain_ollama import OllamaLLM

import mlflow
from mlflow.sklearn import save_model
from mlflow.transformers import log_model
import logging

import config

# %% [markdown]
# ### MLFlow setup

# %%
MODEL_NAME = "llama3.1" 
TRACKING_URI = open("../.mlflow_uri").read().strip()
EXPERIMENT_NAME = config.EXPERIMENT_NAME

logging.basicConfig(format="%(asctime)s: %(message)s") # Configure logging format to show timestamp before every message

logger = logging.getLogger()
logger.setLevel(logging.INFO) # Only show logs that are INFO or more important (e.g., WARNING, ERROR) — but ignore DEBUG.

# %% [markdown]
# ### Load df

# %%
df = pd.read_csv('../data/data_small.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  dataset                                               text
# 0       18384        8  Testing on animals could save the life of you ...  \
# 1       11271        3  I remember when China took over Hong Kong, I r...
# 2       15702        4  : The only "Light at the End of the Tunnel", i...
# 3        7148        3  So you only believe there are two ways to run ...
# 4        8147        3  Keep things the way they are or change them co...
#
#    logical_fallacies source
# 0  appeal_to_emotion    NaN
# 1               none    NaN
# 2  appeal_to_emotion    NaN
# 3               none    NaN
# 4      false_dilemma    NaN

# %% [markdown]
# ### Initialize local model using Ollama

# %%
import warnings
warnings.filterwarnings("ignore")
from langchain_groq import ChatGroq

#temperature is hyperparameter, how creative do I want the llm to be (0 is not creative), sometimes, when it is not 0, it can give you the second likely word

# Initialize the local Llama model using Ollama
llm = OllamaLLM(
    model="deepseek-r1:8b",  # llama3.1:8b, Replace with your desired local Llama model version
    temperature=0,        # No randomness, deterministic output
    max_tokens=None,      # Unlimited token length (adjust as needed)
)

# %% [markdown]
# ### Define a prompt

# %%
def classify_fallacy(text: str) -> str:
    """Classifies text into one of the predefined logical fallacies."""
    try:
        prompt = f"""Classify the following text into exactly one logical fallacy category:
- faulty_generalization
- ad_hominem
- false_dilemma 
- appeal_to_authority
- appeal_to_emotion  
- none

Here are definitions of each category for reference:
1. **Faulty Generalization**: This fallacy occurs when an argument assumes something is true for a large population without having a large enough sample. A kind of overgeneralization.
2. **Ad Hominem**: This fallacy occurs when the speaker is attacking the other person or some aspect of them rather than addressing the argument itself.
3. **False Dilemma**: This fallacy occurs when only two options are presented in an argument, even though more options may exist. A case of “either this or that”.
4. **Appeal to Authority**: This fallacy occurs when an argument relies on the opinion or endorsement of an authority figure who may not have relevant expertise or whose expertise is questionable.
5. **Appeal to Emotion**: This fallacy occurs when emotion is used to support an argument, such as pity, fear, anger, etc.
6. **None**: There are no fallacies in this text!

Here are examples of each category for reference:
1. **Faulty Generalization**: "I read one report about corruption, so that industry must be corrupt."
2. **Ad Hominem**: "Do you even know what you're talking about?"
3. **False Dilemma**: "Do you recommend drinking or injecting bleach to fight Covid?"
4. **Appeal to Authority**: "Trust me, I am a lawyer, so I know how to handle your taxes."
5. **Appeal to Emotion**: "You murdered 100,000 people, called Coronavirus a hoax, fired doctors, and told Americans to inject themselves with bleach. Maybe you should shut the fuck up."
6. **None**: "I don't think that kind of logic is good. It's essentially saying that so long as the authoritarians repress their people enough and nobody can rise up against them, we should think things are okay. We should strive to ensure they have leaders who value democracy, not oppression and authoritarianism."

Text to classify: {text}

Respond ONLY with the category name and nothing else."""

        # Generate response using the local Llama model
        response = llm.invoke(prompt)
        
        # Extract and normalize response content
        prediction = response.strip().lower()
        valid_categories = ["faulty_generalization", "ad_hominem", "false_dilemma", 
                            "appeal_to_authority", "appeal_to_emotion", "none"]
        
        return prediction if prediction in valid_categories else "none"
        
    except Exception as e:
        print(f"Error processing text: {text[:50]}... | Error: {str(e)}")
        return "Error"

# %% [markdown]
# ### Process dataframe

# %%
def process_dataframe(df: pd.DataFrame, batch_size=10) -> pd.DataFrame:
    """Process DataFrame with chunking for better performance."""
    result_df = df.copy()
    
    # Process in smaller batches to reduce errors
    chunks = [df[i:i+batch_size] for i in range(0, len(df), batch_size)]
    
    with tqdm(total=len(df), desc="Classifying Logical Fallacies") as pbar:
        for chunk in chunks:
            chunk_results = []
            for text in chunk['text']:
                result = classify_fallacy(text)
                chunk_results.append(result)
                pbar.update(1)
                
            # Update results for this chunk
            result_df.loc[chunk.index, 'predicted_fallacy'] = chunk_results
    
    return result_df

# %% [markdown]
# ### Make predictions

# %%
# make predictions only based on 1000 rows
df_small = df.iloc[:50]

# %%
# Process the DataFrame and classify logical fallacies
processed_df = process_dataframe(df_small)
# Out:
# Classifying Logical Fallacies:   0%|          | 0/50 [00:00<?, ?it/s]2025-04-04 15:11:51,685: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   2%|▏         | 1/50 [00:15<12:32, 15.35s/it]2025-04-04 15:12:07,251: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   4%|▍         | 2/50 [00:36<15:05, 18.87s/it]2025-04-04 15:12:28,442: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   6%|▌         | 3/50 [01:08<19:33, 24.97s/it]2025-04-04 15:13:00,803: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:   8%|▊         | 4/50 [01:28<17:37, 22.99s/it]2025-04-04 15:13:20,481: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  10%|█         | 5/50 [01:41<14:19, 19.09s/it]2025-04-04 15:13:32,474: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  12%|█▏        | 6/50 [01:57<13:20, 18.20s/it]2025-04-04 15:13:49,567: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  14%|█▍        | 7/50 [02:15<12:52, 17.98s/it]2025-04-04 15:14:06,758: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  16%|█▌        | 8/50 [02:35<13:11, 18.84s/it]2025-04-04 15:14:27,293: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  18%|█▊        | 9/50 [02:50<11:54, 17.43s/it]2025-04-04 15:14:41,482: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  20%|██        | 10/50 [03:11<12:24, 18.61s/it]2025-04-04 15:15:03,216: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  22%|██▏       | 11/50 [03:32<12:41, 19.53s/it]2025-04-04 15:15:24,331: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  24%|██▍       | 12/50 [03:47<11:24, 18.01s/it]2025-04-04 15:15:39,326: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  26%|██▌       | 13/50 [04:04<10:53, 17.67s/it]2025-04-04 15:15:55,751: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:
HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  92%|█████████▏| 46/50 [15:23<01:20, 20.05s/it]2025-04-04 15:27:14,905: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  94%|█████████▍| 47/50 [15:50<01:06, 22.33s/it]2025-04-04 15:27:42,552: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  96%|█████████▌| 48/50 [16:02<00:38, 19.01s/it]2025-04-04 15:27:53,645: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies:  98%|█████████▊| 49/50 [16:19<00:18, 18.46s/it]2025-04-04 15:28:11,003: HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Classifying Logical Fallacies: 100%|██████████| 50/50 [16:37<00:00, 19.95s/it]

# %% [markdown]
# ### Evaluation

# %%
processed_df.head(50)
# Out:
#     Unnamed: 0  dataset                                               text
# 0        18384        8  Testing on animals could save the life of you ...  \
# 1        11271        3  I remember when China took over Hong Kong, I r...
# 2        15702        4  : The only "Light at the End of the Tunnel", i...
# 3         7148        3  So you only believe there are two ways to run ...
# 4         8147        3  Keep things the way they are or change them co...
# 5         4242        2  If you don't agree to sign the labor agreement...
# 6        12550        3  It is true that there are many people in gover...
# 7         8372        3  either the company regularizes those employees...
# 8        12883        4  :   ...  False. Crack is a choice. A once in a...
# 9        19528        9                                  Horribly wounded.
# 10        9773        3  This is the problem with news written in this ...
# 11        3615        2  She's only arguing for this because she works ...
# 12        6783        3  Given that there is such death-grip control ov...
# 13       17541        8  Animals deserve to live, but humans are more i...
# 14        8116        3  This is insane! The strongest person should be...
# 15       10554        3  While I think it's important that groups have ...
# 16       11825        3  I am 45 years old and they have been saying th...
# 17        8141        3  A politician's changing of laws in order to re...
# 18       14069        4  :    Soon to be closed and never reopened.... ...
# 19        9912        3  The funding of these domes at a low cost by th...
# 20       16044        4     : Wake up bleach heads,he cares not Ho h kills
# 21       19044        9  The fact of the matter is the plan is so compl...
# 22       14825        4  : New post: News -> UK Orders 5 Million Modern...
# 23       13468        4  :   Testing isn't free. For everyone so idk wh...
# 24       19526        9  Republicans talk about it, but we're the first...
# 25       17332        8  Yes, refugees who commit crimes have no respec...
# 26       15796        4  :   Never going to happen. 1st, all attempts a...
# 27       15900        4  : Even more dangerous than a strategically sha...
# 28        6798        3  It's great to hear women are breaking into the...
# 29       16852        5  The percentage of Americans with natural immun...
# 30       19388        9           a good job of stripping out the capacity
# 31        1144        1  All things being equal – “ and it ’ s only got...
# 32       19813        9                                 It was a disaster.
# 33       19611        9  Now, finally, if you can't pay the bills you'r...
# 34       13849        4  : Boof with the first crab of the trip. He's a...
# 35        2872        2  If you can't prove that Ken had an affair with...
# 36       14326        4  : Americans are drinking bleach and dunking fo...
# 37        8351        3  Either the protestors are lying or the governm...
# 38       17751        8  Maybe he looked healthy, but other gorillas ar...
# 39        9086        3  In a country that has such bad freedom of expr...
# 40       11899        3  People should be able to tell what they are an...
# 41       17234        8  Yes, because we were attacked, and if we don't...
# 42        9457        3  Either nothing changes or the entire governmen...
# 43       13313        4  : Is there anyone with knowledge concerning th...
# 44       19124        9  I know what it means to see people who are une...
# 45       19874        9  We have dramatically increased control and enf...
# 46       16404        5  “‘The interaction between Arctic ocean tempera...
# 47       16246        5  “Ocean acidification is the terrifying threat ...
# 48       17675        8              we see that you never practice sport!
# 49       16637        5  “Without human intervention, the concentration...
#
#         logical_fallacies                                             source
# 0       appeal_to_emotion                                                NaN  \
# 1                    none                                                NaN
# 2       appeal_to_emotion                                                NaN
# 3                    none                                                NaN
# 4           false_dilemma                                                NaN
# 5       appeal_to_emotion                                                NaN
# 6                    none                                                NaN
# 7           false_dilemma                                                NaN
# 8                    none                                                NaN
# 9       appeal_to_emotion                                                NaN
# 10                   none                                                NaN
# 11             ad_hominem                                                NaN
# 12  faulty_generalization                                                NaN
# 13  faulty_generalization                                                NaN
# 14    appeal_to_authority                                                NaN
# 15                   none                                                NaN
# 16                   none                                                NaN
# 17                   none                                                NaN
# 18                   none                                                NaN
# 19    appeal_to_authority                                                NaN
# 20      appeal_to_emotion                                                NaN
# 21      appeal_to_emotion                                                NaN
# 22                   none                                                NaN
# 23             ad_hominem                                                NaN
# 24      appeal_to_emotion                                                NaN
# 25                   none                                                NaN
# 26      appeal_to_emotion                                                NaN
# 27             ad_hominem                                                NaN
# 28    appeal_to_authority                                                NaN
# 29                   none                                                NaN
# 30      appeal_to_emotion                                                NaN
# 31  faulty_generalization  https://www.theguardian.com/environment/2016/s...
# 32      appeal_to_emotion                                                NaN
# 33      appeal_to_emotion                                                NaN
# 34                   none                                                NaN
# 35          false_dilemma                                                NaN
# 36                   none                                                NaN
# 37          false_dilemma                                                NaN
# 38                   none                                                NaN
# 39                   none                                                NaN
# 40  faulty_generalization                                                NaN
# 41  faulty_generalization                                                NaN
# 42          false_dilemma                                                NaN
# 43                   none                                                NaN
# 44      appeal_to_emotion                                                NaN
# 45      appeal_to_emotion                                                NaN
# 46                   none                                                NaN
# 47    appeal_to_authority                                      article45.txt
# 48             ad_hominem                                                NaN
# 49                   none                                      article64.txt
#
#    predicted_fallacy
# 0               none
# 1               none
# 2               none
# 3               none
# 4               none
# 5               none
# 6               none
# 7               none
# 8               none
# 9               none
# 10              none
# 11              none
# 12              none
# 13              none
# 14              none
# 15              none
# 16              none
# 17              none
# 18              none
# 19              none
# 20              none
# 21              none
# 22              none
# 23              none
# 24              none
# 25              none
# 26              none
# 27              none
# 28              none
# 29              none
# 30              none
# 31              none
# 32              none
# 33              none
# 34              none
# 35              none
# 36              none
# 37              none
# 38              none
# 39              none
# 40              none
# 41              none
# 42              none
# 43              none
# 44              none
# 45              none
# 46              none
# 47              none
# 48              none
# 49              none

# %%
print(classification_report(processed_df["logical_fallacies"], processed_df["predicted_fallacy"]))
# Out:
#                        precision    recall  f1-score   support
#
#            ad_hominem       0.00      0.00      0.00         4
#   appeal_to_authority       0.00      0.00      0.00         4
#     appeal_to_emotion       0.00      0.00      0.00        13
#         false_dilemma       0.00      0.00      0.00         5
# faulty_generalization       0.00      0.00      0.00         5
#                  none       0.38      1.00      0.55        19
#
#              accuracy                           0.38        50
#             macro avg       0.06      0.17      0.09        50
#          weighted avg       0.14      0.38      0.21        50
